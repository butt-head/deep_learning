# %%
# !pip install tensorflow_addons

# %%
#!/usr/bin/env python3
#
# Team members' IDs:
# 182a3da8-8a9e-11ec-986f-f39926f24a9c  (Jan Zubáč)
# 7797f596-9326-11ec-986f-f39926f24a9c
# 449dba85-9adb-11ec-986f-f39926f24a9c
#
import argparse
import datetime
import os
import re
os.environ.setdefault("TF_CPP_MIN_LOG_LEVEL", "2")  # Report only TF errors by default

import numpy as np
import tensorflow as tf

import argparse
import datetime
import os
import re
from typing import Dict
os.environ.setdefault("TF_CPP_MIN_LOG_LEVEL", "2")  # Report only TF errors by default

import tensorflow_addons as tfa

from morpho_analyzer import MorphoAnalyzer
from morpho_dataset import MorphoDataset
from lemmatizer_noattn import Model


# TODO: Define reasonable defaults and optionally more parameters.
# Also, you can set the number of the threads 0 to use all your CPU cores.
# parser = argparse.ArgumentParser()

# parser.add_argument("--batch_size", default=64, type=int, help="Batch size.")
# parser.add_argument("--cle_dim", default=64, type=int, help="CLE embedding dimension.")
# parser.add_argument("--epochs", default=10, type=int, help="Number of epochs.")
# parser.add_argument("--max_sentences", default=None, type=int, help="Maximum number of sentences to load.")
# parser.add_argument("--recodex", default=False, action="store_true", help="Evaluation in ReCodEx.")
# parser.add_argument("--rnn_dim", default=64, type=int, help="RNN cell dimension.")
# parser.add_argument("--seed", default=42, type=int, help="Random seed.")
# parser.add_argument("--threads", default=0, type=int, help="Maximum number of threads to use.")

def main(args: argparse.Namespace) -> None:
    # Fix random seeds and threads
    tf.keras.utils.set_random_seed(args.seed)
    tf.config.threading.set_inter_op_parallelism_threads(args.threads)
    tf.config.threading.set_intra_op_parallelism_threads(args.threads)

    # Create logdir name
    args.logdir = os.path.join("logs", "{}-{}-{}".format(
        os.path.basename(globals().get("__file__", "notebook")),
        datetime.datetime.now().strftime("%Y-%m-%d_%H%M%S"),
        ",".join(("{}={}".format(re.sub("(.)[^_]*_?", r"\1", k), v) for k, v in sorted(vars(args).items())))
    ))

    # Load the data. Using analyses is only optional.
    morpho = MorphoDataset("czech_pdt_lemmas", add_bow_eow=True)
    analyses = MorphoAnalyzer("czech_pdt_analyses")

    # TODO: Create the model and train it
    # Create the model and train
    model = Model(args, morpho.train)

    # Construct dataset for lemmatizer training
    def create_dataset(name):
        dataset = getattr(morpho, name).dataset
        dataset = dataset.map(lambda example: (example["forms"], example["lemmas"]))
        dataset = dataset.shuffle(len(dataset), seed=args.seed) if name == "train" else dataset
        dataset = dataset.apply(tf.data.experimental.dense_to_ragged_batch(args.batch_size))
        return dataset
    train, dev, test = create_dataset("train"), create_dataset("dev"), create_dataset("test")


    class ShowIntermediateResults(tf.keras.callbacks.Callback):
        def __init__(self, data):
            self._iterator = iter(data.repeat())
        def on_train_batch_end(self, batch, logs=None):
            if model.optimizer.iterations % 50 == 0:
                forms, lemmas = next(self._iterator)
                print(model.optimizer.iterations.numpy(),
                      *[repr(strings[0, 0].numpy().decode("utf-8"))
                        for strings in [forms, lemmas, model.predict_on_batch(forms[:1, :1])]])



    logs = model.fit(train, epochs=args.epochs, validation_data=dev, verbose=2,
                    callbacks=[ShowIntermediateResults(dev), model.tb_callback])

    # Generate test set annotations, but in `args.logdir` to allow parallel execution.
    os.makedirs(args.logdir, exist_ok=True)
    with open(os.path.join(args.logdir, "lemmatizer_competition.txt"), "w", encoding="utf-8") as predictions_file:
        # Predict the tags on the test set; update the following prediction
        # command if you use other output structre than in lemmatizer_noattn.
        predictions = model.predict(test)
        for sentence in predictions:
            for word in sentence:
                print(word.numpy().decode("utf-8"), file=predictions_file)
            print(file=predictions_file)


# if __name__ == "__main__":
#     args = parser.parse_args([] if "__file__" not in globals() else None)
#     main(args)

# %%
parser = argparse.ArgumentParser()
parser.add_argument("--batch_size", default=64, type=int, help="Batch size.")
parser.add_argument("--cle_dim", default=64, type=int, help="CLE embedding dimension.")
parser.add_argument("--epochs", default=10, type=int, help="Number of epochs.")
parser.add_argument("--max_sentences", default=None, type=int, help="Maximum number of sentences to load.")
parser.add_argument("--recodex", default=False, action="store_true", help="Evaluation in ReCodEx.")
parser.add_argument("--rnn_dim", default=64, type=int, help="RNN cell dimension.")
parser.add_argument("--seed", default=42, type=int, help="Random seed.")
parser.add_argument("--threads", default=0, type=int, help="Maximum number of threads to use.")

args = parser.parse_args([] if "__file__" not in globals() else None)
print(args)
main(args)
# Out:
# Namespace(batch_size=64, cle_dim=64, epochs=10, max_sentences=None, recodex=False, rnn_dim=64, seed=42, threads=0)
# Epoch 1/10
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("Adam/gradients/concat_1:0", shape=(None,), dtype=int32), values=Tensor("Adam/gradients/concat:0", shape=(None, 64), dtype=float32), dense_shape=Tensor("gradient_tape/model_2/bidirectional_2/forward_gru_2/RaggedToTensor/Shape:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# 50 '|' '|' ''
# 100 'První' 'první-1' 'ooot'
# 150 'Druhá' 'druhý' 'poot'
# 200 'Přesto' 'přesto-1' 'pooott'
# 250 'Do' 'do-1' 'do-1'
# 300 'Pozvání' 'pozvání' 'podavan'
# 350 'Už' 'už-2' 'že-1'
# 400 'Kdo' 'kdo' 'do-1'
# 450 'Nedávno' 'dávno-1' 'dnodný'
# 500 'Zcela' 'zcela' 'zeze'
# 550 'Tento' 'tento' 'tento'
# 600 'Zpočátku' 'zpočátku' 'provitný'
# 650 'Vbrzku' 'vbrzku' 'vruzko'
# 700 'Co' 'co-1' 'ok-1'
# 750 'Základní' 'základní' 'zalákdan'
# 800 'Podle' 'podle-2' 'podle'
# 850 'Zdá' 'zdát' 'zdám'
# 900 'Dále' 'dále-3' 'dále'
# 950 'Jistě' 'jistě' 'jistě'
# 1000 'V' 'v-1' 'v-1'
# 1050 'Na' 'na-1' 'na-1'
# 1100 'Kursy' 'kurs' 'Kurs'
# 1150 'Ctí' 'čest' 'cít'
# 1200 'Svět' 'svět' 'svět'
# 1250 'Zástupce' 'zástupce' 'zásture'
# 1300 'Gibbon' 'Gibbon' 'Gibobno'
# 1350 'Druhým' 'druhý' 'druhý'
# 1400 '"' '"' '"'
# 1417/1417 - 116s - loss: 1.2492 - val_accuracy: 0.6766 - 116s/epoch - 82ms/step
# Epoch 2/10
# 1450 'Suková' 'Suková' 'Sukový'
# 1500 'Doporučujeme' 'doporučovat' 'doporubočat'
# 1550 'Dokončený' 'dokončený' 'dokončený'
# 1600 'Podle' 'podle-2' 'podle-2'
# 1650 'Jisté' 'jistý' 'jistý'
# 1700 'Situaci' 'situace' 'situace'
# 1750 'Vykonávání' 'vykonávání' 'vykonánátnum'
# 1800 'Problematické' 'problematický' 'prodelalicet'
# 1850 'Radost' 'radost' 'radost'
# 1900 'Teprve' 'teprve' 'teprve'
# 1950 'Darja' 'Darja' 'Darova'
# 2000 'Prezídium' 'prezídium' 'prezidumí'
# 2050 'Jižní' 'jižní' 'jižní'
# 2100 'Aby' 'aby' 'aby'
# 2150 'Jím' 'on-1' 'on-1'
# 2200 'Odbytišť' 'odbytiště' 'odbylemší'
# 2250 'Ve' 'v-1' 'v-1'
# 2300 'Úvěry' 'úvěr' 'úvěr'
# 2350 'Pacient' 'pacient' 'paceint'
# 2400 'Valašské' 'valašský' 'Valašský'
# 2450 'Jejich' 'jeho' 'jeho'
# 2500 'Druhou' 'druhý' 'druhý'
# 2550 'Potlačily' 'potlačit' 'potlačit'
# 2600 'Velké' 'velký' 'velký'
# 2650 'Věda' 'věda' 'věda'
# 2700 'Snímky' 'snímek' 'snímek'
# 2750 'Jiří' 'Jiří' 'Jiří'
# 2800 'A' 'a-1' 'a-1'
# 1417/1417 - 107s - loss: 0.2679 - val_accuracy: 0.8144 - 107s/epoch - 75ms/step
# Epoch 3/10
# 2850 'Obě' 'oba' 'oba'
# 2900 'Když' 'když' 'když'
# 2950 'Králíci' 'králík' 'králící'
# 3000 'Lidstvo' 'lidstvo' 'lidstvo'
# 3050 'Problém' 'problém' 'problém'
# 3100 'To' 'ten' 'ten'
# 3150 'Ukazuje' 'ukazovat' 'uzakovat'
# 3200 'Vypravuje' 'vypravovat' 'vypravovat'
# 3250 'Někdo' 'někdo' 'někdo'
# 3300 'Vzhledem' 'vzhledem' 'vzhledem'
# 3350 'Kdo' 'kdo' 'kdo'
# 3400 'Opoziční' 'opoziční' 'opoziční'
# 3450 'V' 'v-1' 'v-1'
# 3500 'Stát' 'stát-1' 'stát-1'
# 3550 'Dlouhodobý' 'dlouhodobý' 'dloudoožlový'
# 3600 'Memorandum' 'memorandum' 'memoranda'
# 3650 'Co' 'co-1' 'co-1'
# 3700 'Výsledky' 'výsledek' 'výsledek'
# 3750 'Oba' 'oba' 'oba'
# 3800 'Rekordní' 'rekordní' 'rekordní'
# 3850 'Trvalo' 'trvat' 'Trvat'
# 3900 'Změnu' 'změna' 'změna'
# 3950 'Než' 'než-2' 'než-2'
# 4000 'Dopadne' 'dopadnout' 'dopadnout'
# 4050 '"' '"' '"'
# 4100 'Po' 'po-1' 'po-1'
# 4150 'Třetiny' 'třetina' 'třetina'
# 4200 'Č' 'český' 'Č-33'
# 4250 'O' 'o-1' 'o-1'
# 1417/1417 - 106s - loss: 0.1633 - val_accuracy: 0.8613 - 106s/epoch - 75ms/step
# Epoch 4/10
# 4300 'ODU' 'ODU-88' 'ODA'
# 4350 '-' '-' '-'
# 4400 'Schumpeterova' 'Schumpeterův' 'Schadereler'
# 4450 'V' 'v-1' 'v-1'
# 4500 'Snaha' 'snaha' 'snaha'
# 4550 'Samostatný' 'samostatný' 'samostatný'
# 4600 'Na' 'na-1' 'na-1'
# 4650 'Proti' 'proti-1' 'proti-1'
# 4700 'ÖMV' 'ÖMV' 'MV-88'
# 4750 'Přímořská' 'přímořský' 'přímořský'
# 4800 'Sampras' 'Sampras' 'Sampras'
# 4850 'K' 'k-1' 'k-1'
# 4900 'Lidé' 'lidé' 'lidé'
# 4950 '"' '"' '"'
# 5000 'Činitelé' 'činitel-1' 'činitel'
# 5050 'Francie' 'Francie' 'Francie'
# 5100 'Další' 'další' 'další'
# 5150 'Projekt' 'projekt' 'projekt'
# 5200 'Tvrzení' 'tvrzení' 'tvrzení'
# 5250 'Máme' 'mít' 'mít'
# 5300 'Nejvyšší' 'vysoký' 'vysoký'
# 5350 'Iluzorní' 'iluzorní' 'ulizounský'
# 5400 'Cenový' 'cenový' 'cenový'
# 5450 'Výše' 'výše' 'výše'
# 5500 'Pokud' 'pokud' 'pokud'
# 5550 'V' 'v-1' 'v-1'
# 5600 'Sprcha' 'sprcha' 'Sprcha'
# 5650 'Sociální' 'sociální' 'sociální'
# 1417/1417 - 106s - loss: 0.1226 - val_accuracy: 0.8847 - 106s/epoch - 75ms/step
# Epoch 5/10
# 5700 'I' 'i-1' 'i-1'
# 5750 '%' '%' '%'
# 5800 'Zdůraznil' 'zdůraznit' 'zdůraznit'
# 5850 '(' '(' '('
# 5900 'Kromě' 'kromě' 'kromě'
# 5950 'Na' 'na-1' 'na-1'
# 6000 'Jako' 'jako-1' 'jako-1'
# 6050 'Dělníci' 'dělník' 'dělník'
# 6100 'Ustanovení' 'ustanovení' 'ustanovení'
# 6150 'Moby' 'Moby' 'Moba'
# 6200 'Ministerstvo' 'ministerstvo' 'ministerstvo'
# 6250 'Rozdíl' 'rozdíl' 'rozdíl'
# 6300 'Lákala' 'lákat' 'lákat'
# 6350 'Možná' 'možná-1' 'možná-1'
# 6400 'A' 'a-1' 'a-1'
# 6450 'Ekologické' 'ekologický' 'ekologický'
# 6500 'Uvede' 'uvést' 'uvést'
# 6550 'Ponechali' 'ponechat' 'ponechat'
# 6600 'Když' 'když' 'když'
# 6650 'Měl' 'mít' 'mít'
# 6700 'Zejména' 'zejména-2' 'zejména-2'
# 6750 'Foto' 'foto' 'foto'
# 6800 'McEnroe' 'McEnroe' 'Mcenren'
# 6850 'A' 'a-1' 'a-1'
# 6900 'Krátce' 'krátce' 'krátce'
# 6950 'K' 'k-1' 'k-1'
# 7000 'Ty' 'ten' 'ten'
# 7050 'Kolika' 'kolik' 'Kolik'
# 1417/1417 - 107s - loss: 0.1008 - val_accuracy: 0.8975 - 107s/epoch - 75ms/step
# Epoch 6/10
# 7100 'Aby' 'aby' 'aby'
# 7150 'To' 'ten' 'ten'
# 7200 'Nikdo' 'nikdo' 'nikdo'
# 7250 'Praha' 'Praha' 'Praha'
# 7300 'Vláda' 'vláda' 'vláda'
# 7350 'V' 'v-1' 'v-1'
# 7400 'Svého' 'svůj-1' 'svůj-1'
# 7450 'Některé' 'některý' 'některý'
# 7500 'Jednání' 'jednání' 'jednání'
# 7550 'Řekněte' 'říci' 'řekně'
# 7600 'Občanské' 'občanský' 'občanský'
# 7650 'Most' 'Most-2' 'most'
# 7700 'Soud' 'soud' 'soud'
# 7750 'Oba' 'oba' 'oba'
# 7800 'Rusko' 'Rusko' 'Rusko'
# 7850 'Obrat' 'obrat-1' 'obrat-1'
# 7900 'Janků' 'Janků' 'Jank'
# 7950 'Sofia' 'Sofie' 'Sofia'
# 8000 'Nepodmíněné' 'podmíněný' 'dodíměnný'
# 8050 'Jak' 'jak-2' 'jak-3'
# 8100 'Ani' 'ani-1' 'ani-1'
# 8150 'Praha' 'Praha' 'Praha'
# 8200 'Je' 'být' 'být'
# 8250 'Mezitím' 'mezitím' 'mezitím'
# 8300 'A' 'a-1' 'a-1'
# 8350 'Všude' 'všude' 'všude'
# 8400 'A' 'a-1' 'a-1'
# 8450 'Takový' 'takový' 'takový'
# 8500 '"' '"' '"'
# 1417/1417 - 107s - loss: 0.0873 - val_accuracy: 0.9037 - 107s/epoch - 75ms/step
# Epoch 7/10
# 8550 'Dříve' 'dříve' 'dříve'
# 8600 'Vývozní' 'vývozní' 'vývozní'
# 8650 'Celkem' 'celkem' 'celkem'
# 8700 'Proč' 'proč' 'proč'
# 8750 'Thoresen' 'Thoresen' 'Thoresí'
# 8800 'Jenže' 'jenže' 'jenže'
# 8850 'V' 'v-1' 'v-1'
# 8900 'Nevelká' 'velký' 'velký'
# 8950 'Tým' 'tým' 'tým'
# 9000 'Soud' 'soud' 'soud'
# 9050 'Je' 'být' 'být'
# 9100 'Divácká' 'divácký' 'divácký'
# 9150 'Plzeň' 'Plzeň' 'Plzeň'
# 9200 'Při' 'při-1' 'při-1'
# 9250 'V' 'v-1' 'v-1'
# 9300 '"' '"' '"'
# 9350 '|' '|' '|'
# 9400 'První' 'první-1' 'první-1'
# 9450 'Druhá' 'druhý' 'druhý'
# 9500 'Přesto' 'přesto-1' 'přesto-1'
# 9550 'Do' 'do-1' 'do-1'
# 9600 'Pozvání' 'pozvání' 'pozvání'
# 9650 'Už' 'už-2' 'už-1'
# 9700 'Kdo' 'kdo' 'kdo'
# 9750 'Nedávno' 'dávno-1' 'dávno-1'
# 9800 'Zcela' 'zcela' 'zcela'
# 9850 'Tento' 'tento' 'tento'
# 9900 'Zpočátku' 'zpočátku' 'zpočátek'
# 1417/1417 - 106s - loss: 0.0779 - val_accuracy: 0.9130 - 106s/epoch - 75ms/step
# Epoch 8/10
# 9950 'Vbrzku' 'vbrzku' 'vbrzka'
# 10000 'Co' 'co-1' 'co-1'
# 10050 'Základní' 'základní' 'základní'
# 10100 'Podle' 'podle-2' 'podle-2'
# 10150 'Zdá' 'zdát' 'zdát'
# 10200 'Dále' 'dále-3' 'dále-3'
# 10250 'Jistě' 'jistě' 'Jistě'
# 10300 'V' 'v-1' 'v-1'
# 10350 'Na' 'na-1' 'na-1'
# 10400 'Kursy' 'kurs' 'Kurs-1'
# 10450 'Ctí' 'čest' 'ctít'
# 10500 'Svět' 'svět' 'svět'
# 10550 'Zástupce' 'zástupce' 'zástupce'
# 10600 'Gibbon' 'Gibbon' 'Gibbon'
# 10650 'Druhým' 'druhý' 'druhý'
# 10700 '"' '"' '"'
# 10750 'Suková' 'Suková' 'Suková'
# 10800 'Doporučujeme' 'doporučovat' 'doporučovat'
# 10850 'Dokončený' 'dokončený' 'dokončený'
# 10900 'Podle' 'podle-2' 'podle-2'
# 10950 'Jisté' 'jistý' 'jistý'
# 11000 'Situaci' 'situace' 'situace'
# 11050 'Vykonávání' 'vykonávání' 'vykonávání'
# 11100 'Problematické' 'problematický' 'problematický'
# 11150 'Radost' 'radost' 'radost'
# 11200 'Teprve' 'teprve' 'teprve'
# 11250 'Darja' 'Darja' 'Darjá'
# 11300 'Prezídium' 'prezídium' 'prezídium'
# 1417/1417 - 106s - loss: 0.0712 - val_accuracy: 0.9175 - 106s/epoch - 75ms/step
# Epoch 9/10
# 11350 'Jižní' 'jižní' 'jižní'
# 11400 'Aby' 'aby' 'aby'
# 11450 'Jím' 'on-1' 'on-1'
# 11500 'Odbytišť' 'odbytiště' 'odbytiště'
# 11550 'Ve' 'v-1' 'v-1'
# 11600 'Úvěry' 'úvěr' 'úvěr'
# 11650 'Pacient' 'pacient' 'Pacient'
# 11700 'Valašské' 'valašský' 'Valašský'
# 11750 'Jejich' 'jeho' 'jeho'
# 11800 'Druhou' 'druhý' 'druhý'
# 11850 'Potlačily' 'potlačit' 'potlačit'
# 11900 'Velké' 'velký' 'velký'
# 11950 'Věda' 'věda' 'věda'
# 12000 'Snímky' 'snímek' 'snímek'
# 12050 'Jiří' 'Jiří' 'Jiří'
# 12100 'A' 'a-1' 'a-1'
# 12150 'Obě' 'oba' 'oba'
# 12200 'Když' 'když' 'když'
# 12250 'Králíci' 'králík' 'králící'
# 12300 'Lidstvo' 'lidstvo' 'lidstvo'
# 12350 'Problém' 'problém' 'problém'
# 12400 'To' 'ten' 'ten'
# 12450 'Ukazuje' 'ukazovat' 'ukazovat'
# 12500 'Vypravuje' 'vypravovat' 'vypravovat'
# 12550 'Někdo' 'někdo' 'někdo'
# 12600 'Vzhledem' 'vzhledem' 'vzhledem'
# 12650 'Kdo' 'kdo' 'kdo'
# 12700 'Opoziční' 'opoziční' 'opoziční'
# 12750 'V' 'v-1' 'v-1'
# 1417/1417 - 106s - loss: 0.0660 - val_accuracy: 0.9199 - 106s/epoch - 75ms/step
# Epoch 10/10
# 12800 'Stát' 'stát-1' 'stát-1'
# 12850 'Dlouhodobý' 'dlouhodobý' 'dlouhodobý'
# 12900 'Memorandum' 'memorandum' 'memorandum'
# 12950 'Co' 'co-1' 'co-1'
# 13000 'Výsledky' 'výsledek' 'výsledek'
# 13050 'Oba' 'oba' 'oba'
# 13100 'Rekordní' 'rekordní' 'rekordní'
# 13150 'Trvalo' 'trvat' 'trvat'
# 13200 'Změnu' 'změna' 'změna'
# 13250 'Než' 'než-2' 'než-2'
# 13300 'Dopadne' 'dopadnout' 'dopadnout'
# 13350 '"' '"' '"'
# 13400 'Po' 'po-1' 'po-1'
# 13450 'Třetiny' 'třetina' 'třetina'
# 13500 'Č' 'český' 'český'
# 13550 'O' 'o-1' 'o-1'
# 13600 'ODU' 'ODU-88' 'ODU'
# 13650 '-' '-' '-'
# 13700 'Schumpeterova' 'Schumpeterův' 'Schutheremba'
# 13750 'V' 'v-1' 'v-1'
# 13800 'Snaha' 'snaha' 'snaha'
# 13850 'Samostatný' 'samostatný' 'samostatný'
# 13900 'Na' 'na-1' 'na-1'
# 13950 'Proti' 'proti-1' 'proti-1'
# 14000 'ÖMV' 'ÖMV' 'MČM'
# 14050 'Přímořská' 'přímořský' 'přímořský'
# 14100 'Sampras' 'Sampras' 'Sampras'
# 14150 'K' 'k-1' 'k-1'
# 1417/1417 - 106s - loss: 0.0620 - val_accuracy: 0.9261 - 106s/epoch - 75ms/step

# %%
parser = argparse.ArgumentParser()
parser.add_argument("--batch_size", default=32, type=int, help="Batch size.")
parser.add_argument("--cle_dim", default=128, type=int, help="CLE embedding dimension.")
parser.add_argument("--epochs", default=10, type=int, help="Number of epochs.")
parser.add_argument("--max_sentences", default=None, type=int, help="Maximum number of sentences to load.")
parser.add_argument("--recodex", default=False, action="store_true", help="Evaluation in ReCodEx.")
parser.add_argument("--rnn_dim", default=128, type=int, help="RNN cell dimension.")
parser.add_argument("--seed", default=42, type=int, help="Random seed.")
parser.add_argument("--threads", default=0, type=int, help="Maximum number of threads to use.")

args = parser.parse_args([] if "__file__" not in globals() else None)
print(args)
main(args)
# Out:
# Namespace(batch_size=32, cle_dim=128, epochs=10, max_sentences=None, recodex=False, rnn_dim=128, seed=42, threads=0)
# Epoch 1/10
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("Adam/gradients/concat_1:0", shape=(None,), dtype=int32), values=Tensor("Adam/gradients/concat:0", shape=(None, 128), dtype=float32), dense_shape=Tensor("gradient_tape/model_4/bidirectional_4/forward_gru_4/RaggedToTensor/Shape:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# 50 '|' '|' ''
# 100 'Zkrácená' 'zkrácený' 'poooott'
# 150 'První' 'první-1' 'povov-1'
# 200 'Nejdříve' 'dříve' 'vevevení'
# 250 'Druhá' 'druhý' 'rrár'
# 300 'Znamená' 'znamenat' 'znantan'
# 350 'Přesto' 'přesto-1' 'přest'
# 400 'Při' 'při-1' 'při-1'
# 450 'Do' 'do-1' 'do-1'
# 500 'Abychom' 'aby' 'abych'
# 550 'Pozvání' 'pozvání' 'pozvání'
# 600 'Je' 'být' 'být'
# 650 'Už' 'už-2' 'už-1'
# 700 'Janáček' 'Janáček' 'Janáčký'
# 750 'Kdo' 'kdo' 'kdo'
# 800 'Překvapit' 'překvapit' 'překvařit'
# 850 'Nedávno' 'dávno-1' 'dávnout'
# 900 'Pak' 'pak' 'pak'
# 950 'Zcela' 'zcela' 'Zcela'
# 1000 'V' 'v-1' 'v-1'
# 1050 'Tento' 'tento' 'tento'
# 1100 'Pan' 'Pan-1' 'Pan'
# 1150 'Zpočátku' 'zpočátku' 'zpočátek'
# 1200 '9' '9' '9'
# 1250 'Vbrzku' 'vbrzku' 'vbrák'
# 1300 'Jako' 'jako-1' 'jako-1'
# 1350 'Co' 'co-1' 'co-1'
# 1400 'Siemens' 'Siemens-1' 'Siemens-1'
# 1450 'Základní' 'základní' 'základní'
# 1500 'Pozor' 'pozor-1' 'Pozor'
# 1550 'Podle' 'podle-2' 'podle-2'
# 1600 'V' 'v-1' 'v-1'
# 1650 'Zdá' 'zdát' 'zdát'
# 1700 'Akcionáři' 'akcionář' 'akcionář'
# 1750 'Dále' 'dále-3' 'Dále-3'
# 1800 'Za' 'za' 'za'
# 1850 'Jistě' 'jistě' 'jistě'
# 1900 'Sobotního' 'sobotní' 'sobotní'
# 1950 'V' 'v-1' 'v-1'
# 2000 'Tam' 'tam' 'tam'
# 2050 'Na' 'na-1' 'na-1'
# 2100 '"' '"' '"'
# 2150 'Kursy' 'kurs' 'Kurs'
# 2200 'Vyšetřování' 'vyšetřování' 'vyšetřování'
# 2250 'Ctí' 'čest' 'ctí'
# 2300 'Rumunská' 'rumunský' 'rumunský'
# 2350 'Svět' 'svět' 'svět'
# 2400 'S' 's-1' 's-1'
# 2450 'Zástupce' 'zástupce' 'zástupce'
# 2500 'Týž' 'týž' 'týž'
# 2550 'Gibbon' 'Gibbon' 'Gbibon'
# 2600 'O' 'o-1' 'o-1'
# 2650 'Druhým' 'druhý' 'druhý'
# 2700 'Zavalitý' 'zavalitý' 'zavalitý'
# 2750 '"' '"' '"'
# 2800 'Tak' 'tak-3' 'tak-3'
# 2834/2834 - 199s - loss: 0.4506 - val_accuracy: 0.9034 - 199s/epoch - 70ms/step
# Epoch 2/10
# 2850 'Suková' 'Suková' 'Sukový'
# 2900 'PLÁNY' 'plán' 'plán'
# 2950 'Doporučujeme' 'doporučovat' 'doporučovat'
# 3000 'Když' 'když' 'když'
# 3050 'Dokončený' 'dokončený' 'dokončený'
# 3100 'Bakalářství' 'bakalářství' 'bakalářský'
# 3150 'Podle' 'podle-2' 'podle-2'
# 3200 'V' 'v-1' 'v-1'
# 3250 'Jisté' 'jistý' 'jistý'
# 3300 'Informovala' 'informovat' 'informovat'
# 3350 'Situaci' 'situace' 'situace'
# 3400 'De' 'De-77' 'De-77'
# 3450 'Vykonávání' 'vykonávání' 'vykonávání'
# 3500 'Tato' 'tento' 'tento'
# 3550 'Problematické' 'problematický' 'problematický'
# 3600 '"' '"' '"'
# 3650 'Radost' 'radost' 'radost'
# 3700 'Rusko' 'Rusko' 'Rusko'
# 3750 'Teprve' 'teprve' 'Teprve'
# 3800 'Ale' 'ale' 'ale'
# 3850 'Darja' 'Darja' 'Darja'
# 3900 'Jindy' 'jindy' 'jindy'
# 3950 'Prezídium' 'prezídium' 'prezídium'
# 4000 'Vojenská' 'vojenský' 'vojenský'
# 4050 'Jižní' 'jižní' 'jižní'
# 4100 'Nabízíme' 'nabízet' 'nabízet'
# 4150 'Aby' 'aby' 'aby'
# 4200 'Poslední' 'poslední' 'poslední'
# 4250 'Jím' 'on-1' 'on-1'
# 4300 'Parlament' 'parlament' 'parlament'
# 4350 'Odbytišť' 'odbytiště' 'odbytiště'
# 4400 'K' 'k-1' 'k-1'
# 4450 'Ve' 'v-1' 'v-1'
# 4500 '58' '58' '58'
# 4550 'Úvěry' 'úvěr' 'úvěr'
# 4600 'Naopak' 'naopak-1' 'naopak-1'
# 4650 'Pacient' 'pacient' 'pacient'
# 4700 'MĚSTSKÉ' 'městský' 'městský'
# 4750 'Valašské' 'valašský' 'valašský'
# 4800 'Současné' 'současný' 'současný'
# 4850 'Jejich' 'jeho' 'jeho'
# 4900 'Na' 'na-1' 'na-1'
# 4950 'Druhou' 'druhý' 'druhý'
# 5000 'Adaptace' 'adaptace' 'adaptace'
# 5050 'Potlačily' 'potlačit' 'potlačit'
# 5100 'Tím' 'ten' 'ten'
# 5150 'Velké' 'velký' 'velký'
# 5200 'Nebo' 'nebo' 'nebo'
# 5250 'Věda' 'věda' 'věda'
# 5300 'Například' 'například' 'například'
# 5350 'Snímky' 'snímek' 'snímek'
# 5400 'Kresba' 'kresba' 'Kresba'
# 5450 'Jiří' 'Jiří' 'Jiří'
# 5500 'Tam' 'tam' 'tam'
# 5550 'A' 'a-1' 'a-1'
# 5600 'Křehký' 'křehký' 'křehký'
# 5650 'Obě' 'oba' 'oba'
# 2834/2834 - 191s - loss: 0.0657 - val_accuracy: 0.9308 - 191s/epoch - 67ms/step
# Epoch 3/10
# 5700 'Vysoký' 'vysoký' 'vysoký'
# 5750 'Když' 'když' 'když'
# 5800 '(' '(' '('
# 5850 'Králíci' 'králík' 'Králíc'
# 5900 'Přímé' 'přímý' 'přímý'
# 5950 'Lidstvo' 'lidstvo' 'lidstvo'
# 6000 'To' 'ten' 'ten'
# 6050 'Problém' 'problém' 'problém'
# 6100 'Zároveň' 'zároveň' 'zároveň'
# 6150 'To' 'ten' 'ten'
# 6200 'Je' 'být' 'být'
# 6250 'Ukazuje' 'ukazovat' 'ukazovat'
# 6300 'Teprve' 'teprve' 'teprve'
# 6350 'Vypravuje' 'vypravovat' 'vypravovat'
# 6400 'Patrně' 'patrně' 'Patrně'
# 6450 'Někdo' 'někdo' 'někdo'
# 6500 'Maximální' 'maximální' 'maximální'
# 6550 'Vzhledem' 'vzhledem' 'vzhledem'
# 6600 'Předehrávka' 'předehrávka' 'přederkávka'
# 6650 'Kdo' 'kdo' 'kdo'
# 6700 'Oslavy' 'oslava' 'Oslava'
# 6750 'Opoziční' 'opoziční' 'opoziční'
# 6800 'Jak' 'jak-3' 'jak-3'
# 6850 'V' 'v-1' 'v-1'
# 6900 'Vedoucí' 'vedoucí-2' 'vedoucí'
# 6950 'Stát' 'stát-1' 'stát-1'
# 7000 '(' '(' '('
# 7050 'Dlouhodobý' 'dlouhodobý' 'dlouhodobý'
# 7100 'Podle' 'podle-2' 'podle-2'
# 7150 'Memorandum' 'memorandum' 'memorandum'
# 7200 'jejich' 'jeho' 'jeho'
# 7250 'Co' 'co-1' 'co-1'
# 7300 'Masaryk' 'Masaryk' 'Masaryk'
# 7350 'Výsledky' 'výsledek' 'výsledek'
# 7400 'Po' 'po-1' 'po-1'
# 7450 'Oba' 'oba' 'oba'
# 7500 'Skutečnost' 'skutečnost' 'skutečnost'
# 7550 'Rekordní' 'rekordní' 'rekordní'
# 7600 '"' '"' '"'
# 7650 'Trvalo' 'trvat' 'trval'
# 7700 'problémem' 'problém' 'problém'
# 7750 'Změnu' 'změna' 'změna'
# 7800 'Ruský' 'ruský' 'ruský'
# 7850 'Než' 'než-2' 'než-2'
# 7900 'Vzpomínání' 'vzpomínání' 'vzpomínání'
# 7950 'Dopadne' 'dopadnout' 'dopadnout'
# 8000 'Teď' 'teď' 'teď'
# 8050 '"' '"' '"'
# 8100 'RADAROVÝ' 'radarový' 'radarový'
# 8150 'Po' 'po-1' 'po-1'
# 8200 'HOKEJOVOU' 'hokejový' 'hokejový'
# 8250 'Třetiny' 'třetina' 'třetina'
# 8300 'Vopat' 'Vopat' 'vopat'
# 8350 'Č' 'český' 'Č-33'
# 8400 'Program' 'program-1' 'program-1'
# 8450 'O' 'o-1' 'o-1'
# 8500 'Jinými' 'jiný' 'jiný'
# 2834/2834 - 190s - loss: 0.0455 - val_accuracy: 0.9323 - 190s/epoch - 67ms/step
# Epoch 4/10
# 8550 'ODU' 'ODU-88' 'ODum'
# 8600 'Byl' 'být' 'být'
# 8650 '-' '-' '-'
# 8700 'Etika' 'etika' 'etika'
# 8750 'Schumpeterova' 'Schumpeterův' 'Schumpetův'
# 8800 'Jelikož' 'jelikož' 'jelikož'
# 8850 'V' 'v-1' 'v-1'
# 8900 'Právě' 'právě-1' 'právě-1'
# 8950 'Snaha' 'snaha' 'snaha'
# 9000 '5355405185.5' '5355405185.5' '53515.8515.0'
# 9050 'Samostatný' 'samostatný' 'samostatný'
# 9100 'Zatímco' 'zatímco' 'zatímco'
# 9150 'Na' 'na-1' 'na-1'
# 9200 'Například' 'například' 'například'
# 9250 'Proti' 'proti-1' 'proti-1'
# 9300 '1' '1' '1'
# 9350 'ÖMV' 'ÖMV' 'CMV-88'
# 9400 'Finále' 'finále' 'finále'
# 9450 'Přímořská' 'přímořský' 'přímořský'
# 9500 'Varšava' 'Varšava' 'Varšava'
# 9550 'Sampras' 'Sampras' 'Sampras'
# 9600 '-' '-' '-'
# 9650 'K' 'k-1' 'k-1'
# 9700 'Kalkata' 'Kalkata' 'kalkat'
# 9750 'Lidé' 'lidé' 'lidé'
# 9800 'Podle' 'podle-2' 'podle-2'
# 9850 '"' '"' '"'
# 9900 'Pro' 'pro-1' 'pro-1'
# 9950 'Činitelé' 'činitel-1' 'činitel-1'
# 10000 'Z' 'z-1' 'z-1'
# 10050 'Francie' 'Francie' 'Francie'
# 10100 'Hudební' 'hudební' 'hudební'
# 10150 'Další' 'další' 'další'
# 10200 'Praha' 'Praha' 'Praha'
# 10250 'Projekt' 'projekt' 'projekt'
# 10300 'PŘÍPAD' 'případ' 'případ'
# 10350 'Tvrzení' 'tvrzení' 'tvrzení'
# 10400 'tenisovým' 'tenisový' 'tenisový'
# 10450 'Máme' 'mít' 'mít'
# 10500 'Opět' 'opět' 'opět'
# 10550 'Nejvyšší' 'vysoký' 'vysoký'
# 10600 'Ty' 'ten' 'ten'
# 10650 'Iluzorní' 'iluzorní' 'Iluzorní-1'
# 10700 'Alexej' 'Alexej' 'Alex-1'
# 10750 'Cenový' 'cenový' 'cenový'
# 10800 'Co' 'co-1' 'co-1'
# 10850 'Výše' 'výše' 'výše'
# 10900 'Zájem' 'zájem' 'zájem'
# 10950 'Pokud' 'pokud' 'pokud'
# 11000 '*' '*' '*'
# 11050 'V' 'v-1' 'v-1'
# 11100 'Voda' 'voda' 'voda'
# 11150 'Sprcha' 'sprcha' 'sprcha'
# 11200 'Stejné' 'stejný' 'stejný'
# 11250 'Sociální' 'sociální' 'sociální'
# 11300 'Pomocným' 'pomocný' 'pomocný'
# 2834/2834 - 191s - loss: 0.0372 - val_accuracy: 0.9480 - 191s/epoch - 67ms/step
# Epoch 5/10
# 11350 'I' 'i-1' 'i-1'
# 11400 'Sleva' 'sleva' 'Sleva'
# 11450 '%' '%' '%'
# 11500 'Zdánlivě' 'zdánlivě' 'zdánlivě'
# 11550 'Zdůraznil' 'zdůraznit' 'zdůraznit'
# 11600 'Dvanáct' 'dvanáct' 'dvanáct'
# 11650 '(' '(' '('
# 11700 'Praha' 'Praha' 'Praha'
# 11750 'Kromě' 'kromě' 'kromě'
# 11800 'Kromě' 'kromě' 'kromě'
# 11850 'Na' 'na-1' 'na-1'
# 11900 'Míra' 'míra' 'míra'
# 11950 'Jako' 'jako-1' 'jako-1'
# 12000 'Město' 'město' 'město'
# 12050 'Dělníci' 'dělník' 'dělník'
# 12100 'Podle' 'podle-2' 'podle-2'
# 12150 'Ustanovení' 'ustanovení' 'ustanovení'
# 12200 'Žadatel' 'žadatel' 'žadatel'
# 12250 'Moby' 'Moby' 'Moby'
# 12300 'Krátce' 'krátce' 'krátce'
# 12350 'Ministerstvo' 'ministerstvo' 'ministerstvo'
# 12400 'Přitom' 'přitom' 'přitom'
# 12450 'Rozdíl' 'rozdíl' 'rozdíl'
# 12500 'Bez' 'bez-1' 'bez-1'
# 12550 'Lákala' 'lákat' 'Lákal'
# 12600 'Jste' 'být' 'být'
# 12650 'Možná' 'možná-1' 'možná-1'
# 12700 'Zdeno' 'Zdeno' 'zdeno'
# 12750 'A' 'a-1' 'a-1'
# 12800 'Nový' 'nový' 'nový'
# 12850 'Ekologické' 'ekologický' 'ekologický'
# 12900 'Za' 'za' 'za'
# 12950 'Uvede' 'uvést' 'uvést'
# 13000 'Karel' 'Karel' 'Karel'
# 13050 'Ponechali' 'ponechat' 'ponechat'
# 13100 'Ty' 'ten' 'ten'
# 13150 'Když' 'když' 'když'
# 13200 'Antidumpingová' 'antidumpingový' 'antidvanigovný'
# 13250 'Měl' 'mít' 'mít'
# 13300 'Chátrá' 'chátrat' 'Chátrat'
# 13350 'Zejména' 'zejména-2' 'zejména-2'
# 13400 'Kostky' 'kostka' 'kostka'
# 13450 'Foto' 'foto' 'foto'
# 13500 'Jiří' 'Jiří' 'Jiří'
# 13550 'McEnroe' 'McEnroe' 'McEnroer'
# 13600 'Český' 'český' 'český'
# 13650 'A' 'a-1' 'a-1'
# 13700 'Jsem' 'být' 'být'
# 13750 'Krátce' 'krátce' 'krátce'
# 13800 'To' 'ten' 'ten'
# 13850 'K' 'k-1' 'k-1'
# 13900 'Sdělil' 'sdělit' 'sdělit'
# 13950 'Ty' 'ten' 'ten'
# 14000 'Změnil' 'změnit' 'změnit'
# 14050 'Kolika' 'kolik' 'koliko'
# 14100 'Není' 'být' 'být'
# 14150 'Aby' 'aby' 'aby'
# 2834/2834 - 191s - loss: 0.0323 - val_accuracy: 0.9508 - 191s/epoch - 67ms/step
# Epoch 6/10
# 14200 'Jako' 'jako-1' 'jako-1'
# 14250 'To' 'ten' 'ten'
# 14300 'Jestli' 'jestli' 'jestli'
# 14350 'Nikdo' 'nikdo' 'nikdo'
# 14400 'Z' 'z-1' 'z-1'
# 14450 'Praha' 'Praha' 'Praha'
# 14500 'Praha' 'Praha' 'Praha'
# 14550 'Vláda' 'vláda' 'vláda'
# 14600 'Podle' 'podle-2' 'podle-2'
# 14650 'V' 'v-1' 'v-1'
# 14700 'Festival' 'festival' 'festival'
# 14750 'Svého' 'svůj-1' 'svůj-1'
# 14800 'Průměrné' 'průměrný' 'průměrný'
# 14850 'Některé' 'některý' 'některý'
# 14900 'Téhož' 'týž' 'týž'
# 14950 'Jednání' 'jednání' 'jednání'
# 15000 'Fond' 'fond' 'fond'
# 15050 'Řekněte' 'říci' 'říci'
# 15100 'Důvěřoval' 'důvěřovat' 'důvěřovat'
# 15150 'Občanské' 'občanský' 'občanský'
# 15200 'Lásky' 'láska' 'láska'
# 15250 'Most' 'Most-2' 'Most-2'
# 15300 'Před' 'před-1' 'před-1'
# 15350 'Soud' 'soud' 'soud'
# 15400 'Jak' 'jak-2' 'jak-3'
# 15450 'Oba' 'oba' 'oba'
# 15500 'Ačkoli' 'ačkoli' 'ačkoli'
# 15550 'Rusko' 'Rusko' 'Rusko'
# 15600 'Změnit' 'změnit' 'změnit'
# 15650 'Obrat' 'obrat-1' 'obrat-1'
# 15700 'Většina' 'většina' 'většina'
# 15750 'Janků' 'Janků' 'Janků'
# 15800 'Pominutelný' 'pominutelný' 'pominutelný'
# 15850 'Sofia' 'Sofie' 'Sofia'
# 15900 'Dvacátého' 'dvacátý' 'dvacátý'
# 15950 'Nepodmíněné' 'podmíněný' 'podmíněný'
# 16000 'Čeští' 'český' 'český'
# 16050 'Jak' 'jak-2' 'jak-3'
# 16100 'Vládne' 'vládnout' 'vládno'
# 16150 'Ani' 'ani-1' 'ani-1'
# 16200 'Třeba' 'třeba-1' 'třeba-1'
# 16250 'Praha' 'Praha' 'Praha'
# 16300 'Pod' 'pod-1' 'pod-1'
# 16350 'Je' 'být' 'být'
# 16400 'nemohou' 'moci' 'moci'
# 16450 'Mezitím' 'mezitím' 'mezitím'
# 16500 'Musím' 'muset' 'muset'
# 16550 'A' 'a-1' 'a-1'
# 16600 'Socialismus' 'socialismus' 'socialismus'
# 16650 'Všude' 'všude' 'všude'
# 16700 'Světa' 'svět' 'svět'
# 16750 'A' 'a-1' 'a-1'
# 16800 'Manažer' 'manažer-1' 'manažer-1'
# 16850 'Takový' 'takový' 'takový'
# 16900 'Soud' 'soud' 'soud'
# 16950 '"' '"' '"'
# 17000 'Na' 'na-1' 'na-1'
# 2834/2834 - 192s - loss: 0.0291 - val_accuracy: 0.9553 - 192s/epoch - 68ms/step
# Epoch 7/10
# 17050 'Dříve' 'dříve' 'dříve'
# 17100 'Předkladatelé' 'předkladatel' 'předkladatel'
# 17150 'Vývozní' 'vývozní' 'vývozní'
# 17200 'Rozpočet' 'rozpočet' 'rozpočet'
# 17250 'Celkem' 'celkem' 'celkem'
# 17300 'Dnešní' 'dnešní' 'dnešní'
# 17350 'Proč' 'proč' 'proč'
# 17400 'Televize' 'televize' 'televize'
# 17450 'Thoresen' 'Thoresen' 'Thoresen'
# 17500 'Památce' 'památka' 'památka'
# 17550 'Jenže' 'jenže' 'jenže'
# 17600 'Československá' 'československý' 'československý'
# 17650 'V' 'v-1' 'v-1'
# 17700 'Z' 'z-1' 'z-1'
# 17750 'Nevelká' 'velký' 'velký'
# 17800 'Ale' 'ale' 'ale'
# 17850 'Tým' 'tým' 'tým'
# 17900 'Vzhledem' 'vzhledem' 'vzhledem'
# 17950 'Soud' 'soud' 'soud'
# 18000 'Inspektoři' 'inspektor' 'Inspektor'
# 18050 'Je' 'být' 'být'
# 18100 'Ve' 'v-1' 'v-1'
# 18150 'Divácká' 'divácký' 'divácký'
# 18200 'Pan' 'pan' 'pan'
# 18250 'Plzeň' 'Plzeň' 'Plzeň'
# 18300 'Banka' 'banka' 'banka'
# 18350 'Při' 'při-1' 'při-1'
# 18400 'Za' 'za' 'za'
# 18450 'V' 'v-1' 'v-1'
# 18500 'Předpokládá' 'předpokládat' 'předpokládat'
# 18550 '"' '"' '"'
# 18600 'Bratislava' 'Bratislava' 'Bratislava'
# 18650 '|' '|' '|'
# 18700 'Zkrácená' 'zkrácený' 'zkrácený'
# 18750 'První' 'první-1' 'první-1'
# 18800 'Nejdříve' 'dříve' 'dříve'
# 18850 'Druhá' 'druhý' 'druhý'
# 18900 'Znamená' 'znamenat' 'znamenat'
# 18950 'Přesto' 'přesto-1' 'přesto-1'
# 19000 'Při' 'při-1' 'při-1'
# 19050 'Do' 'do-1' 'do-1'
# 19100 'Abychom' 'aby' 'aby'
# 19150 'Pozvání' 'pozvání' 'pozvání'
# 19200 'Je' 'být' 'být'
# 19250 'Už' 'už-2' 'už-1'
# 19300 'Janáček' 'Janáček' 'Janáček'
# 19350 'Kdo' 'kdo' 'kdo'
# 19400 'Překvapit' 'překvapit' 'překvapit'
# 19450 'Nedávno' 'dávno-1' 'dávno-1'
# 19500 'Pak' 'pak' 'pak'
# 19550 'Zcela' 'zcela' 'zcela'
# 19600 'V' 'v-1' 'v-1'
# 19650 'Tento' 'tento' 'tento'
# 19700 'Pan' 'Pan-1' 'pan'
# 19750 'Zpočátku' 'zpočátku' 'zpočátku'
# 19800 '9' '9' '9'
# 2834/2834 - 193s - loss: 0.0268 - val_accuracy: 0.9575 - 193s/epoch - 68ms/step
# Epoch 8/10
# 19850 'Vbrzku' 'vbrzku' 'vbrzku'
# 19900 'Jako' 'jako-1' 'jako-1'
# 19950 'Co' 'co-1' 'co-1'
# 20000 'Siemens' 'Siemens-1' 'Siemens-1'
# 20050 'Základní' 'základní' 'základní'
# 20100 'Pozor' 'pozor-1' 'pozor-1'
# 20150 'Podle' 'podle-2' 'podle-2'
# 20200 'V' 'v-1' 'v-1'
# 20250 'Zdá' 'zdát' 'zdát'
# 20300 'Akcionáři' 'akcionář' 'akcionář'
# 20350 'Dále' 'dále-3' 'dále-3'
# 20400 'Za' 'za' 'za'
# 20450 'Jistě' 'jistě' 'jistě'
# 20500 'Sobotního' 'sobotní' 'sobotní'
# 20550 'V' 'v-1' 'v-1'
# 20600 'Tam' 'tam' 'tam'
# 20650 'Na' 'na-1' 'na-1'
# 20700 '"' '"' '"'
# 20750 'Kursy' 'kurs' 'kurs'
# 20800 'Vyšetřování' 'vyšetřování' 'vyšetřování'
# 20850 'Ctí' 'čest' 'ctít'
# 20900 'Rumunská' 'rumunský' 'rumunský'
# 20950 'Svět' 'svět' 'svět'
# 21000 'S' 's-1' 's-1'
# 21050 'Zástupce' 'zástupce' 'zástupce'
# 21100 'Týž' 'týž' 'týž'
# 21150 'Gibbon' 'Gibbon' 'Gibbon'
# 21200 'O' 'o-1' 'o-1'
# 21250 'Druhým' 'druhý' 'druhý'
# 21300 'Zavalitý' 'zavalitý' 'zavalitý'
# 21350 '"' '"' '"'
# 21400 'Tak' 'tak-3' 'tak-3'
# 21450 'Suková' 'Suková' 'Suková'
# 21500 'PLÁNY' 'plán' 'plán'
# 21550 'Doporučujeme' 'doporučovat' 'doporučovat'
# 21600 'Když' 'když' 'když'
# 21650 'Dokončený' 'dokončený' 'dokončený'
# 21700 'Bakalářství' 'bakalářství' 'bakalářství'
# 21750 'Podle' 'podle-2' 'podle-2'
# 21800 'V' 'v-1' 'v-1'
# 21850 'Jisté' 'jistý' 'jistý'
# 21900 'Informovala' 'informovat' 'informovat'
# 21950 'Situaci' 'situace' 'situace'
# 22000 'De' 'De-77' 'De-77'
# 22050 'Vykonávání' 'vykonávání' 'vykonávání'
# 22100 'Tato' 'tento' 'tento'
# 22150 'Problematické' 'problematický' 'problematický'
# 22200 '"' '"' '"'
# 22250 'Radost' 'radost' 'radost'
# 22300 'Rusko' 'Rusko' 'Rusko'
# 22350 'Teprve' 'teprve' 'teprve'
# 22400 'Ale' 'ale' 'ale'
# 22450 'Darja' 'Darja' 'Darja-1'
# 22500 'Jindy' 'jindy' 'jindy'
# 22550 'Prezídium' 'prezídium' 'prezídium'
# 22600 'Vojenská' 'vojenský' 'vojenský'
# 22650 'Jižní' 'jižní' 'jižní'
# 2834/2834 - 192s - loss: 0.0251 - val_accuracy: 0.9570 - 192s/epoch - 68ms/step
# Epoch 9/10
# 22700 'Nabízíme' 'nabízet' 'nabízet'
# 22750 'Aby' 'aby' 'aby'
# 22800 'Poslední' 'poslední' 'poslední'
# 22850 'Jím' 'on-1' 'on-1'
# 22900 'Parlament' 'parlament' 'parlament'
# 22950 'Odbytišť' 'odbytiště' 'obydtišit'
# 23000 'K' 'k-1' 'k-1'
# 23050 'Ve' 'v-1' 'v-1'
# 23100 '58' '58' '58'
# 23150 'Úvěry' 'úvěr' 'úvěr'
# 23200 'Naopak' 'naopak-1' 'naopak-1'
# 23250 'Pacient' 'pacient' 'pacient'
# 23300 'MĚSTSKÉ' 'městský' 'městský'
# 23350 'Valašské' 'valašský' 'valašský'
# 23400 'Současné' 'současný' 'současný'
# 23450 'Jejich' 'jeho' 'jeho'
# 23500 'Na' 'na-1' 'na-1'
# 23550 'Druhou' 'druhý' 'druhý'
# 23600 'Adaptace' 'adaptace' 'adaptace'
# 23650 'Potlačily' 'potlačit' 'potlačit'
# 23700 'Tím' 'ten' 'ten'
# 23750 'Velké' 'velký' 'velký'
# 23800 'Nebo' 'nebo' 'nebo'
# 23850 'Věda' 'věda' 'věda'
# 23900 'Například' 'například' 'například'
# 23950 'Snímky' 'snímek' 'snímek'
# 24000 'Kresba' 'kresba' 'Kresba'
# 24050 'Jiří' 'Jiří' 'Jiří'
# 24100 'Tam' 'tam' 'tam'
# 24150 'A' 'a-1' 'A-33'
# 24200 'Křehký' 'křehký' 'křehký'
# 24250 'Obě' 'oba' 'oba'
# 24300 'Vysoký' 'vysoký' 'vysoký'
# 24350 'Když' 'když' 'když'
# 24400 '(' '(' '('
# 24450 'Králíci' 'králík' 'Králík'
# 24500 'Přímé' 'přímý' 'přímý'
# 24550 'Lidstvo' 'lidstvo' 'Lidstvo'
# 24600 'To' 'ten' 'ten'
# 24650 'Problém' 'problém' 'problém'
# 24700 'Zároveň' 'zároveň' 'zároveň'
# 24750 'To' 'ten' 'ten'
# 24800 'Je' 'být' 'být'
# 24850 'Ukazuje' 'ukazovat' 'ukazovat'
# 24900 'Teprve' 'teprve' 'teprve'
# 24950 'Vypravuje' 'vypravovat' 'vypravovat'
# 25000 'Patrně' 'patrně' 'patrně'
# 25050 'Někdo' 'někdo' 'někdo'
# 25100 'Maximální' 'maximální' 'maximální'
# 25150 'Vzhledem' 'vzhledem' 'vzhledem'
# 25200 'Předehrávka' 'předehrávka' 'předehrávka'
# 25250 'Kdo' 'kdo' 'kdo'
# 25300 'Oslavy' 'oslava' 'Oslava'
# 25350 'Opoziční' 'opoziční' 'opoziční'
# 25400 'Jak' 'jak-3' 'jak-3'
# 25450 'V' 'v-1' 'v-1'
# 25500 'Vedoucí' 'vedoucí-2' 'vedoucí-2'
# 2834/2834 - 193s - loss: 0.0237 - val_accuracy: 0.9569 - 193s/epoch - 68ms/step
# Epoch 10/10
# 25550 'Stát' 'stát-1' 'stát-1'
# 25600 '(' '(' '('
# 25650 'Dlouhodobý' 'dlouhodobý' 'dlouhodobý'
# 25700 'Podle' 'podle-2' 'podle-2'
# 25750 'Memorandum' 'memorandum' 'memorandum'
# 25800 'jejich' 'jeho' 'jeho'
# 25850 'Co' 'co-1' 'co-1'
# 25900 'Masaryk' 'Masaryk' 'Masaryk'
# 25950 'Výsledky' 'výsledek' 'výsledek'
# 26000 'Po' 'po-1' 'po-1'
# 26050 'Oba' 'oba' 'oba'
# 26100 'Skutečnost' 'skutečnost' 'skutečnost'
# 26150 'Rekordní' 'rekordní' 'rekordní'
# 26200 '"' '"' '"'
# 26250 'Trvalo' 'trvat' 'trvat'
# 26300 'problémem' 'problém' 'problém'
# 26350 'Změnu' 'změna' 'změna'
# 26400 'Ruský' 'ruský' 'ruský'
# 26450 'Než' 'než-2' 'než-2'
# 26500 'Vzpomínání' 'vzpomínání' 'vzpomínání'
# 26550 'Dopadne' 'dopadnout' 'dopadnout'
# 26600 'Teď' 'teď' 'teď'
# 26650 '"' '"' '"'
# 26700 'RADAROVÝ' 'radarový' 'Radarový'
# 26750 'Po' 'po-1' 'po-1'
# 26800 'HOKEJOVOU' 'hokejový' 'hokejový'
# 26850 'Třetiny' 'třetina' 'třetina'
# 26900 'Vopat' 'Vopat' 'Vopat'
# 26950 'Č' 'český' 'český'
# 27000 'Program' 'program-1' 'program-1'
# 27050 'O' 'o-1' 'o-1'
# 27100 'Jinými' 'jiný' 'jiný'
# 27150 'ODU' 'ODU-88' 'ODU'
# 27200 'Byl' 'být' 'být'
# 27250 '-' '-' '-'
# 27300 'Etika' 'etika' 'Etika'
# 27350 'Schumpeterova' 'Schumpeterův' 'Schumpeterův'
# 27400 'Jelikož' 'jelikož' 'jelikož'
# 27450 'V' 'v-1' 'v-1'
# 27500 'Právě' 'právě-1' 'právě-1'
# 27550 'Snaha' 'snaha' 'snaha'
# 27600 '5355405185.5' '5355405185.5' '535515.585'
# 27650 'Samostatný' 'samostatný' 'samostatný'
# 27700 'Zatímco' 'zatímco' 'zatímco'
# 27750 'Na' 'na-1' 'na-1'
# 27800 'Například' 'například' 'například'
# 27850 'Proti' 'proti-1' 'proti-1'
# 27900 '1' '1' '1'
# 27950 'ÖMV' 'ÖMV' 'ÖMV-88'
# 28000 'Finále' 'finále' 'finále'
# 28050 'Přímořská' 'přímořský' 'přímořský'
# 28100 'Varšava' 'Varšava' 'Varšava'
# 28150 'Sampras' 'Sampras' 'Sampras'
# 28200 '-' '-' '-'
# 28250 'K' 'k-1' 'k-1'
# 28300 'Kalkata' 'Kalkata' 'kalkata'
# 2834/2834 - 192s - loss: 0.0225 - val_accuracy: 0.9602 - 192s/epoch - 68ms/step

# %%
parser = argparse.ArgumentParser()
parser.add_argument("--batch_size", default=32, type=int, help="Batch size.")
parser.add_argument("--cle_dim", default=128, type=int, help="CLE embedding dimension.")
parser.add_argument("--epochs", default=25, type=int, help="Number of epochs.")
parser.add_argument("--max_sentences", default=None, type=int, help="Maximum number of sentences to load.")
parser.add_argument("--recodex", default=False, action="store_true", help="Evaluation in ReCodEx.")
parser.add_argument("--rnn_dim", default=128, type=int, help="RNN cell dimension.")
parser.add_argument("--seed", default=42, type=int, help="Random seed.")
parser.add_argument("--threads", default=0, type=int, help="Maximum number of threads to use.")

args = parser.parse_args([] if "__file__" not in globals() else None)
print(args)
main(args)
# Out:
# Namespace(batch_size=32, cle_dim=128, epochs=25, max_sentences=None, recodex=False, rnn_dim=128, seed=42, threads=0)
# Epoch 1/25
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("Adam/gradients/concat_1:0", shape=(None,), dtype=int32), values=Tensor("Adam/gradients/concat:0", shape=(None, 128), dtype=float32), dense_shape=Tensor("gradient_tape/model_5/bidirectional_5/forward_gru_5/RaggedToTensor/Shape:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# 50 '|' '|' ''
# 100 'Zkrácená' 'zkrácený' 'poooott'
# 150 'První' 'první-1' 'povov-1'
# 200 'Nejdříve' 'dříve' 'vevevení'
# 250 'Druhá' 'druhý' 'rrár'
# 300 'Znamená' 'znamenat' 'znantan'
# 350 'Přesto' 'přesto-1' 'přest'
# 400 'Při' 'při-1' 'při-1'
# 450 'Do' 'do-1' 'do-1'
# 500 'Abychom' 'aby' 'abych'
# 550 'Pozvání' 'pozvání' 'pozvání'
# 600 'Je' 'být' 'být'
# 650 'Už' 'už-2' 'už-1'
# 700 'Janáček' 'Janáček' 'Janáčký'
# 750 'Kdo' 'kdo' 'kdo'
# 800 'Překvapit' 'překvapit' 'překvařit'
# 850 'Nedávno' 'dávno-1' 'dávnout'
# 900 'Pak' 'pak' 'pak'
# 950 'Zcela' 'zcela' 'Zcela'
# 1000 'V' 'v-1' 'v-1'
# 1050 'Tento' 'tento' 'tento'
# 1100 'Pan' 'Pan-1' 'Pan'
# 1150 'Zpočátku' 'zpočátku' 'zpočátek'
# 1200 '9' '9' '9'
# 1250 'Vbrzku' 'vbrzku' 'vbrák'
# 1300 'Jako' 'jako-1' 'jako-1'
# 1350 'Co' 'co-1' 'co-1'
# 1400 'Siemens' 'Siemens-1' 'Siemens-1'
# 1450 'Základní' 'základní' 'základní'
# 1500 'Pozor' 'pozor-1' 'Pozor'
# 1550 'Podle' 'podle-2' 'podle-2'
# 1600 'V' 'v-1' 'v-1'
# 1650 'Zdá' 'zdát' 'zdát'
# 1700 'Akcionáři' 'akcionář' 'akcionář'
# 1750 'Dále' 'dále-3' 'Dále-3'
# 1800 'Za' 'za' 'za'
# 1850 'Jistě' 'jistě' 'jistě'
# 1900 'Sobotního' 'sobotní' 'sobotní'
# 1950 'V' 'v-1' 'v-1'
# 2000 'Tam' 'tam' 'tam'
# 2050 'Na' 'na-1' 'na-1'
# 2100 '"' '"' '"'
# 2150 'Kursy' 'kurs' 'Kurs'
# 2200 'Vyšetřování' 'vyšetřování' 'vyšetřování'
# 2250 'Ctí' 'čest' 'ctí'
# 2300 'Rumunská' 'rumunský' 'rumunský'
# 2350 'Svět' 'svět' 'svět'
# 2400 'S' 's-1' 's-1'
# 2450 'Zástupce' 'zástupce' 'zástupce'
# 2500 'Týž' 'týž' 'týž'
# 2550 'Gibbon' 'Gibbon' 'Gbibon'
# 2600 'O' 'o-1' 'o-1'
# 2650 'Druhým' 'druhý' 'druhý'
# 2700 'Zavalitý' 'zavalitý' 'zavalitý'
# 2750 '"' '"' '"'
# 2800 'Tak' 'tak-3' 'tak-3'
# 2834/2834 - 204s - loss: 0.4506 - val_accuracy: 0.9034 - 204s/epoch - 72ms/step
# Epoch 2/25
# 2850 'Suková' 'Suková' 'Sukový'
# 2900 'PLÁNY' 'plán' 'plán'
# 2950 'Doporučujeme' 'doporučovat' 'doporučovat'
# 3000 'Když' 'když' 'když'
# 3050 'Dokončený' 'dokončený' 'dokončený'
# 3100 'Bakalářství' 'bakalářství' 'bakalářský'
# 3150 'Podle' 'podle-2' 'podle-2'
# 3200 'V' 'v-1' 'v-1'
# 3250 'Jisté' 'jistý' 'jistý'
# 3300 'Informovala' 'informovat' 'informovat'
# 3350 'Situaci' 'situace' 'situace'
# 3400 'De' 'De-77' 'De-77'
# 3450 'Vykonávání' 'vykonávání' 'vykonávání'
# 3500 'Tato' 'tento' 'tento'
# 3550 'Problematické' 'problematický' 'problematický'
# 3600 '"' '"' '"'
# 3650 'Radost' 'radost' 'radost'
# 3700 'Rusko' 'Rusko' 'Rusko'
# 3750 'Teprve' 'teprve' 'Teprve'
# 3800 'Ale' 'ale' 'ale'
# 3850 'Darja' 'Darja' 'Darja'
# 3900 'Jindy' 'jindy' 'jindy'
# 3950 'Prezídium' 'prezídium' 'prezídium'
# 4000 'Vojenská' 'vojenský' 'vojenský'
# 4050 'Jižní' 'jižní' 'jižní'
# 4100 'Nabízíme' 'nabízet' 'nabízet'
# 4150 'Aby' 'aby' 'aby'
# 4200 'Poslední' 'poslední' 'poslední'
# 4250 'Jím' 'on-1' 'on-1'
# 4300 'Parlament' 'parlament' 'parlament'
# 4350 'Odbytišť' 'odbytiště' 'odbytiště'
# 4400 'K' 'k-1' 'k-1'
# 4450 'Ve' 'v-1' 'v-1'
# 4500 '58' '58' '58'
# 4550 'Úvěry' 'úvěr' 'úvěr'
# 4600 'Naopak' 'naopak-1' 'naopak-1'
# 4650 'Pacient' 'pacient' 'pacient'
# 4700 'MĚSTSKÉ' 'městský' 'městský'
# 4750 'Valašské' 'valašský' 'valašský'
# 4800 'Současné' 'současný' 'současný'
# 4850 'Jejich' 'jeho' 'jeho'
# 4900 'Na' 'na-1' 'na-1'
# 4950 'Druhou' 'druhý' 'druhý'
# 5000 'Adaptace' 'adaptace' 'adaptace'
# 5050 'Potlačily' 'potlačit' 'potlačit'
# 5100 'Tím' 'ten' 'ten'
# 5150 'Velké' 'velký' 'velký'
# 5200 'Nebo' 'nebo' 'nebo'
# 5250 'Věda' 'věda' 'věda'
# 5300 'Například' 'například' 'například'
# 5350 'Snímky' 'snímek' 'snímek'
# 5400 'Kresba' 'kresba' 'Kresba'
# 5450 'Jiří' 'Jiří' 'Jiří'
# 5500 'Tam' 'tam' 'tam'
# 5550 'A' 'a-1' 'a-1'
# 5600 'Křehký' 'křehký' 'křehký'
# 5650 'Obě' 'oba' 'oba'
# 2834/2834 - 198s - loss: 0.0657 - val_accuracy: 0.9308 - 198s/epoch - 70ms/step
# Epoch 3/25
# 5700 'Vysoký' 'vysoký' 'vysoký'
# 5750 'Když' 'když' 'když'
# 5800 '(' '(' '('
# 5850 'Králíci' 'králík' 'Králíc'
# 5900 'Přímé' 'přímý' 'přímý'
# 5950 'Lidstvo' 'lidstvo' 'lidstvo'
# 6000 'To' 'ten' 'ten'
# 6050 'Problém' 'problém' 'problém'
# 6100 'Zároveň' 'zároveň' 'zároveň'
# 6150 'To' 'ten' 'ten'
# 6200 'Je' 'být' 'být'
# 6250 'Ukazuje' 'ukazovat' 'ukazovat'
# 6300 'Teprve' 'teprve' 'teprve'
# 6350 'Vypravuje' 'vypravovat' 'vypravovat'
# 6400 'Patrně' 'patrně' 'Patrně'
# 6450 'Někdo' 'někdo' 'někdo'
# 6500 'Maximální' 'maximální' 'maximální'
# 6550 'Vzhledem' 'vzhledem' 'vzhledem'
# 6600 'Předehrávka' 'předehrávka' 'přederkávka'
# 6650 'Kdo' 'kdo' 'kdo'
# 6700 'Oslavy' 'oslava' 'Oslava'
# 6750 'Opoziční' 'opoziční' 'opoziční'
# 6800 'Jak' 'jak-3' 'jak-3'
# 6850 'V' 'v-1' 'v-1'
# 6900 'Vedoucí' 'vedoucí-2' 'vedoucí'
# 6950 'Stát' 'stát-1' 'stát-1'
# 7000 '(' '(' '('
# 7050 'Dlouhodobý' 'dlouhodobý' 'dlouhodobý'
# 7100 'Podle' 'podle-2' 'podle-2'
# 7150 'Memorandum' 'memorandum' 'memorandum'
# 7200 'jejich' 'jeho' 'jeho'
# 7250 'Co' 'co-1' 'co-1'
# 7300 'Masaryk' 'Masaryk' 'Masaryk'
# 7350 'Výsledky' 'výsledek' 'výsledek'
# 7400 'Po' 'po-1' 'po-1'
# 7450 'Oba' 'oba' 'oba'
# 7500 'Skutečnost' 'skutečnost' 'skutečnost'
# 7550 'Rekordní' 'rekordní' 'rekordní'
# 7600 '"' '"' '"'
# 7650 'Trvalo' 'trvat' 'trval'
# 7700 'problémem' 'problém' 'problém'
# 7750 'Změnu' 'změna' 'změna'
# 7800 'Ruský' 'ruský' 'ruský'
# 7850 'Než' 'než-2' 'než-2'
# 7900 'Vzpomínání' 'vzpomínání' 'vzpomínání'
# 7950 'Dopadne' 'dopadnout' 'dopadnout'
# 8000 'Teď' 'teď' 'teď'
# 8050 '"' '"' '"'
# 8100 'RADAROVÝ' 'radarový' 'radarový'
# 8150 'Po' 'po-1' 'po-1'
# 8200 'HOKEJOVOU' 'hokejový' 'hokejový'
# 8250 'Třetiny' 'třetina' 'třetina'
# 8300 'Vopat' 'Vopat' 'vopat'
# 8350 'Č' 'český' 'Č-33'
# 8400 'Program' 'program-1' 'program-1'
# 8450 'O' 'o-1' 'o-1'
# 8500 'Jinými' 'jiný' 'jiný'
# 2834/2834 - 196s - loss: 0.0455 - val_accuracy: 0.9319 - 196s/epoch - 69ms/step
# Epoch 4/25
# 8550 'ODU' 'ODU-88' 'ODum'
# 8600 'Byl' 'být' 'být'
# 8650 '-' '-' '-'
# 8700 'Etika' 'etika' 'etika'
# 8750 'Schumpeterova' 'Schumpeterův' 'Schumpetův'
# 8800 'Jelikož' 'jelikož' 'jelikož'
# 8850 'V' 'v-1' 'v-1'
# 8900 'Právě' 'právě-1' 'právě-1'
# 8950 'Snaha' 'snaha' 'snaha'
# 9000 '5355405185.5' '5355405185.5' '53515.85515'
# 9050 'Samostatný' 'samostatný' 'samostatný'
# 9100 'Zatímco' 'zatímco' 'zatímco'
# 9150 'Na' 'na-1' 'na-1'
# 9200 'Například' 'například' 'například'
# 9250 'Proti' 'proti-1' 'proti-1'
# 9300 '1' '1' '1'
# 9350 'ÖMV' 'ÖMV' 'CMV-88'
# 9400 'Finále' 'finále' 'finále'
# 9450 'Přímořská' 'přímořský' 'přímořský'
# 9500 'Varšava' 'Varšava' 'Varšava'
# 9550 'Sampras' 'Sampras' 'Sampras'
# 9600 '-' '-' '-'
# 9650 'K' 'k-1' 'k-1'
# 9700 'Kalkata' 'Kalkata' 'kalkat'
# 9750 'Lidé' 'lidé' 'lidé'
# 9800 'Podle' 'podle-2' 'podle-2'
# 9850 '"' '"' '"'
# 9900 'Pro' 'pro-1' 'pro-1'
# 9950 'Činitelé' 'činitel-1' 'činitel-1'
# 10000 'Z' 'z-1' 'z-1'
# 10050 'Francie' 'Francie' 'Francie'
# 10100 'Hudební' 'hudební' 'hudební'
# 10150 'Další' 'další' 'další'
# 10200 'Praha' 'Praha' 'Praha'
# 10250 'Projekt' 'projekt' 'projekt'
# 10300 'PŘÍPAD' 'případ' 'případ'
# 10350 'Tvrzení' 'tvrzení' 'tvrzení'
# 10400 'tenisovým' 'tenisový' 'tenisový'
# 10450 'Máme' 'mít' 'mít'
# 10500 'Opět' 'opět' 'opět'
# 10550 'Nejvyšší' 'vysoký' 'vysoký'
# 10600 'Ty' 'ten' 'ten'
# 10650 'Iluzorní' 'iluzorní' 'Iluzorní'
# 10700 'Alexej' 'Alexej' 'Alex-1'
# 10750 'Cenový' 'cenový' 'cenový'
# 10800 'Co' 'co-1' 'co-1'
# 10850 'Výše' 'výše' 'výše'
# 10900 'Zájem' 'zájem' 'zájem'
# 10950 'Pokud' 'pokud' 'pokud'
# 11000 '*' '*' '*'
# 11050 'V' 'v-1' 'v-1'
# 11100 'Voda' 'voda' 'voda'
# 11150 'Sprcha' 'sprcha' 'sprcha'
# 11200 'Stejné' 'stejný' 'stejný'
# 11250 'Sociální' 'sociální' 'sociální'
# 11300 'Pomocným' 'pomocný' 'pomocný'
# 2834/2834 - 196s - loss: 0.0372 - val_accuracy: 0.9484 - 196s/epoch - 69ms/step
# Epoch 5/25
# 11350 'I' 'i-1' 'i-1'
# 11400 'Sleva' 'sleva' 'Sleva'
# 11450 '%' '%' '%'
# 11500 'Zdánlivě' 'zdánlivě' 'zdánlivě'
# 11550 'Zdůraznil' 'zdůraznit' 'zdůraznit'
# 11600 'Dvanáct' 'dvanáct' 'dvanáct'
# 11650 '(' '(' '('
# 11700 'Praha' 'Praha' 'Praha'
# 11750 'Kromě' 'kromě' 'kromě'
# 11800 'Kromě' 'kromě' 'kromě'
# 11850 'Na' 'na-1' 'na-1'
# 11900 'Míra' 'míra' 'míra'
# 11950 'Jako' 'jako-1' 'jako-1'
# 12000 'Město' 'město' 'město'
# 12050 'Dělníci' 'dělník' 'dělník'
# 12100 'Podle' 'podle-2' 'podle-2'
# 12150 'Ustanovení' 'ustanovení' 'ustanovení'
# 12200 'Žadatel' 'žadatel' 'žadatel'
# 12250 'Moby' 'Moby' 'Moby'
# 12300 'Krátce' 'krátce' 'krátce'
# 12350 'Ministerstvo' 'ministerstvo' 'ministerstvo'
# 12400 'Přitom' 'přitom' 'přitom'
# 12450 'Rozdíl' 'rozdíl' 'rozdíl'
# 12500 'Bez' 'bez-1' 'bez-1'
# 12550 'Lákala' 'lákat' 'Lákal'
# 12600 'Jste' 'být' 'být'
# 12650 'Možná' 'možná-1' 'možná-1'
# 12700 'Zdeno' 'Zdeno' 'zdeno'
# 12750 'A' 'a-1' 'a-1'
# 12800 'Nový' 'nový' 'nový'
# 12850 'Ekologické' 'ekologický' 'ekologický'
# 12900 'Za' 'za' 'za'
# 12950 'Uvede' 'uvést' 'uvést'
# 13000 'Karel' 'Karel' 'Karel'
# 13050 'Ponechali' 'ponechat' 'ponechat'
# 13100 'Ty' 'ten' 'ten'
# 13150 'Když' 'když' 'když'
# 13200 'Antidumpingová' 'antidumpingový' 'antidmupingový'
# 13250 'Měl' 'mít' 'mít'
# 13300 'Chátrá' 'chátrat' 'Chátrat'
# 13350 'Zejména' 'zejména-2' 'zejména-2'
# 13400 'Kostky' 'kostka' 'kostka'
# 13450 'Foto' 'foto' 'foto'
# 13500 'Jiří' 'Jiří' 'Jiří'
# 13550 'McEnroe' 'McEnroe' 'McEnroer'
# 13600 'Český' 'český' 'český'
# 13650 'A' 'a-1' 'a-1'
# 13700 'Jsem' 'být' 'být'
# 13750 'Krátce' 'krátce' 'krátce'
# 13800 'To' 'ten' 'ten'
# 13850 'K' 'k-1' 'k-1'
# 13900 'Sdělil' 'sdělit' 'sdělit'
# 13950 'Ty' 'ten' 'ten'
# 14000 'Změnil' 'změnit' 'změnit'
# 14050 'Kolika' 'kolik' 'koliko'
# 14100 'Není' 'být' 'být'
# 14150 'Aby' 'aby' 'aby'
# 2834/2834 - 195s - loss: 0.0323 - val_accuracy: 0.9510 - 195s/epoch - 69ms/step
# Epoch 6/25
# 14200 'Jako' 'jako-1' 'jako-1'
# 14250 'To' 'ten' 'ten'
# 14300 'Jestli' 'jestli' 'jestli'
# 14350 'Nikdo' 'nikdo' 'nikdo'
# 14400 'Z' 'z-1' 'z-1'
# 14450 'Praha' 'Praha' 'Praha'
# 14500 'Praha' 'Praha' 'Praha'
# 14550 'Vláda' 'vláda' 'vláda'
# 14600 'Podle' 'podle-2' 'podle-2'
# 14650 'V' 'v-1' 'v-1'
# 14700 'Festival' 'festival' 'festival'
# 14750 'Svého' 'svůj-1' 'svůj-1'
# 14800 'Průměrné' 'průměrný' 'průměrný'
# 14850 'Některé' 'některý' 'některý'
# 14900 'Téhož' 'týž' 'týž'
# 14950 'Jednání' 'jednání' 'jednání'
# 15000 'Fond' 'fond' 'fond'
# 15050 'Řekněte' 'říci' 'říci'
# 15100 'Důvěřoval' 'důvěřovat' 'důvěřovat'
# 15150 'Občanské' 'občanský' 'občanský'
# 15200 'Lásky' 'láska' 'láska'
# 15250 'Most' 'Most-2' 'Most-2'
# 15300 'Před' 'před-1' 'před-1'
# 15350 'Soud' 'soud' 'soud'
# 15400 'Jak' 'jak-2' 'jak-3'
# 15450 'Oba' 'oba' 'oba'
# 15500 'Ačkoli' 'ačkoli' 'ačkoli'
# 15550 'Rusko' 'Rusko' 'Rusko'
# 15600 'Změnit' 'změnit' 'změnit'
# 15650 'Obrat' 'obrat-1' 'obrat-1'
# 15700 'Většina' 'většina' 'většina'
# 15750 'Janků' 'Janků' 'Janků'
# 15800 'Pominutelný' 'pominutelný' 'pominutelný'
# 15850 'Sofia' 'Sofie' 'Sofia'
# 15900 'Dvacátého' 'dvacátý' 'dvacátý'
# 15950 'Nepodmíněné' 'podmíněný' 'podmíněný'
# 16000 'Čeští' 'český' 'český'
# 16050 'Jak' 'jak-2' 'jak-3'
# 16100 'Vládne' 'vládnout' 'vládno'
# 16150 'Ani' 'ani-1' 'ani-1'
# 16200 'Třeba' 'třeba-1' 'třeba-1'
# 16250 'Praha' 'Praha' 'Praha'
# 16300 'Pod' 'pod-1' 'pod-1'
# 16350 'Je' 'být' 'být'
# 16400 'nemohou' 'moci' 'moci'
# 16450 'Mezitím' 'mezitím' 'mezitím'
# 16500 'Musím' 'muset' 'muset'
# 16550 'A' 'a-1' 'a-1'
# 16600 'Socialismus' 'socialismus' 'socialismus'
# 16650 'Všude' 'všude' 'všude'
# 16700 'Světa' 'svět' 'svět'
# 16750 'A' 'a-1' 'a-1'
# 16800 'Manažer' 'manažer-1' 'manažer-1'
# 16850 'Takový' 'takový' 'takový'
# 16900 'Soud' 'soud' 'soud'
# 16950 '"' '"' '"'
# 17000 'Na' 'na-1' 'na-1'
# 2834/2834 - 196s - loss: 0.0291 - val_accuracy: 0.9547 - 196s/epoch - 69ms/step
# Epoch 7/25
# 17050 'Dříve' 'dříve' 'dříve'
# 17100 'Předkladatelé' 'předkladatel' 'předkladatel'
# 17150 'Vývozní' 'vývozní' 'vývozní'
# 17200 'Rozpočet' 'rozpočet' 'rozpočet'
# 17250 'Celkem' 'celkem' 'celkem'
# 17300 'Dnešní' 'dnešní' 'dnešní'
# 17350 'Proč' 'proč' 'proč'
# 17400 'Televize' 'televize' 'televize'
# 17450 'Thoresen' 'Thoresen' 'Thoresen'
# 17500 'Památce' 'památka' 'památka'
# 17550 'Jenže' 'jenže' 'jenže'
# 17600 'Československá' 'československý' 'československý'
# 17650 'V' 'v-1' 'v-1'
# 17700 'Z' 'z-1' 'z-1'
# 17750 'Nevelká' 'velký' 'velký'
# 17800 'Ale' 'ale' 'ale'
# 17850 'Tým' 'tým' 'tým'
# 17900 'Vzhledem' 'vzhledem' 'vzhledem'
# 17950 'Soud' 'soud' 'soud'
# 18000 'Inspektoři' 'inspektor' 'Inspektor'
# 18050 'Je' 'být' 'být'
# 18100 'Ve' 'v-1' 'v-1'
# 18150 'Divácká' 'divácký' 'divácký'
# 18200 'Pan' 'pan' 'pan'
# 18250 'Plzeň' 'Plzeň' 'Plzeň'
# 18300 'Banka' 'banka' 'banka'
# 18350 'Při' 'při-1' 'při-1'
# 18400 'Za' 'za' 'za'
# 18450 'V' 'v-1' 'v-1'
# 18500 'Předpokládá' 'předpokládat' 'předpokládat'
# 18550 '"' '"' '"'
# 18600 'Bratislava' 'Bratislava' 'Bratislava'
# 18650 '|' '|' '|'
# 18700 'Zkrácená' 'zkrácený' 'zkrácený'
# 18750 'První' 'první-1' 'první-1'
# 18800 'Nejdříve' 'dříve' 'dříve'
# 18850 'Druhá' 'druhý' 'druhý'
# 18900 'Znamená' 'znamenat' 'znamenat'
# 18950 'Přesto' 'přesto-1' 'přesto-1'
# 19000 'Při' 'při-1' 'při-1'
# 19050 'Do' 'do-1' 'do-1'
# 19100 'Abychom' 'aby' 'aby'
# 19150 'Pozvání' 'pozvání' 'pozvání'
# 19200 'Je' 'být' 'být'
# 19250 'Už' 'už-2' 'už-1'
# 19300 'Janáček' 'Janáček' 'Janáček'
# 19350 'Kdo' 'kdo' 'kdo'
# 19400 'Překvapit' 'překvapit' 'překvapit'
# 19450 'Nedávno' 'dávno-1' 'dávno-1'
# 19500 'Pak' 'pak' 'pak'
# 19550 'Zcela' 'zcela' 'zcela'
# 19600 'V' 'v-1' 'v-1'
# 19650 'Tento' 'tento' 'tento'
# 19700 'Pan' 'Pan-1' 'pan'
# 19750 'Zpočátku' 'zpočátku' 'zpočátku'
# 19800 '9' '9' '9'
# 2834/2834 - 196s - loss: 0.0268 - val_accuracy: 0.9583 - 196s/epoch - 69ms/step
# Epoch 8/25
# 19850 'Vbrzku' 'vbrzku' 'vbrzka'
# 19900 'Jako' 'jako-1' 'jako-1'
# 19950 'Co' 'co-1' 'co-1'
# 20000 'Siemens' 'Siemens-1' 'Siemens-1'
# 20050 'Základní' 'základní' 'základní'
# 20100 'Pozor' 'pozor-1' 'pozor-1'
# 20150 'Podle' 'podle-2' 'podle-2'
# 20200 'V' 'v-1' 'v-1'
# 20250 'Zdá' 'zdát' 'zdát'
# 20300 'Akcionáři' 'akcionář' 'akcionář'
# 20350 'Dále' 'dále-3' 'dále-3'
# 20400 'Za' 'za' 'za'
# 20450 'Jistě' 'jistě' 'jistě'
# 20500 'Sobotního' 'sobotní' 'sobotní'
# 20550 'V' 'v-1' 'v-1'
# 20600 'Tam' 'tam' 'tam'
# 20650 'Na' 'na-1' 'na-1'
# 20700 '"' '"' '"'
# 20750 'Kursy' 'kurs' 'kurs'
# 20800 'Vyšetřování' 'vyšetřování' 'vyšetřování'
# 20850 'Ctí' 'čest' 'ctít'
# 20900 'Rumunská' 'rumunský' 'rumunský'
# 20950 'Svět' 'svět' 'svět'
# 21000 'S' 's-1' 's-1'
# 21050 'Zástupce' 'zástupce' 'zástupce'
# 21100 'Týž' 'týž' 'týž'
# 21150 'Gibbon' 'Gibbon' 'Gibbon'
# 21200 'O' 'o-1' 'o-1'
# 21250 'Druhým' 'druhý' 'druhý'
# 21300 'Zavalitý' 'zavalitý' 'zavalitý'
# 21350 '"' '"' '"'
# 21400 'Tak' 'tak-3' 'tak-3'
# 21450 'Suková' 'Suková' 'Suková'
# 21500 'PLÁNY' 'plán' 'plán'
# 21550 'Doporučujeme' 'doporučovat' 'doporučovat'
# 21600 'Když' 'když' 'když'
# 21650 'Dokončený' 'dokončený' 'dokončený'
# 21700 'Bakalářství' 'bakalářství' 'bakalářstáví'
# 21750 'Podle' 'podle-2' 'podle-2'
# 21800 'V' 'v-1' 'v-1'
# 21850 'Jisté' 'jistý' 'jistý'
# 21900 'Informovala' 'informovat' 'informovat'
# 21950 'Situaci' 'situace' 'situace'
# 22000 'De' 'De-77' 'De-77'
# 22050 'Vykonávání' 'vykonávání' 'vykonávání'
# 22100 'Tato' 'tento' 'tento'
# 22150 'Problematické' 'problematický' 'problematický'
# 22200 '"' '"' '"'
# 22250 'Radost' 'radost' 'radost'
# 22300 'Rusko' 'Rusko' 'Rusko'
# 22350 'Teprve' 'teprve' 'teprve'
# 22400 'Ale' 'ale' 'ale'
# 22450 'Darja' 'Darja' 'Darja-77'
# 22500 'Jindy' 'jindy' 'jindy'
# 22550 'Prezídium' 'prezídium' 'prezídium'
# 22600 'Vojenská' 'vojenský' 'vojenský'
# 22650 'Jižní' 'jižní' 'jižní'
# 2834/2834 - 195s - loss: 0.0250 - val_accuracy: 0.9562 - 195s/epoch - 69ms/step
# Epoch 9/25
# 22700 'Nabízíme' 'nabízet' 'nabízet'
# 22750 'Aby' 'aby' 'aby'
# 22800 'Poslední' 'poslední' 'poslední'
# 22850 'Jím' 'on-1' 'on-1'
# 22900 'Parlament' 'parlament' 'parlament'
# 22950 'Odbytišť' 'odbytiště' 'odbytiště'
# 23000 'K' 'k-1' 'k-1'
# 23050 'Ve' 'v-1' 'v-1'
# 23100 '58' '58' '58'
# 23150 'Úvěry' 'úvěr' 'úvěr'
# 23200 'Naopak' 'naopak-1' 'naopak-1'
# 23250 'Pacient' 'pacient' 'pacient'
# 23300 'MĚSTSKÉ' 'městský' 'městský'
# 23350 'Valašské' 'valašský' 'valašský'
# 23400 'Současné' 'současný' 'současný'
# 23450 'Jejich' 'jeho' 'jeho'
# 23500 'Na' 'na-1' 'na-1'
# 23550 'Druhou' 'druhý' 'druhý'
# 23600 'Adaptace' 'adaptace' 'adaptace'
# 23650 'Potlačily' 'potlačit' 'potlačit'
# 23700 'Tím' 'ten' 'ten'
# 23750 'Velké' 'velký' 'velký'
# 23800 'Nebo' 'nebo' 'nebo'
# 23850 'Věda' 'věda' 'věda'
# 23900 'Například' 'například' 'například'
# 23950 'Snímky' 'snímek' 'snímek'
# 24000 'Kresba' 'kresba' 'kresba'
# 24050 'Jiří' 'Jiří' 'Jiří'
# 24100 'Tam' 'tam' 'tam'
# 24150 'A' 'a-1' 'A-33'
# 24200 'Křehký' 'křehký' 'křehký'
# 24250 'Obě' 'oba' 'oba'
# 24300 'Vysoký' 'vysoký' 'vysoký'
# 24350 'Když' 'když' 'když'
# 24400 '(' '(' '('
# 24450 'Králíci' 'králík' 'Králík'
# 24500 'Přímé' 'přímý' 'přímý'
# 24550 'Lidstvo' 'lidstvo' 'Lidstvo'
# 24600 'To' 'ten' 'ten'
# 24650 'Problém' 'problém' 'problém'
# 24700 'Zároveň' 'zároveň' 'zároveň'
# 24750 'To' 'ten' 'ten'
# 24800 'Je' 'být' 'být'
# 24850 'Ukazuje' 'ukazovat' 'ukazovat'
# 24900 'Teprve' 'teprve' 'teprve'
# 24950 'Vypravuje' 'vypravovat' 'vypravovat'
# 25000 'Patrně' 'patrně' 'patrně'
# 25050 'Někdo' 'někdo' 'někdo'
# 25100 'Maximální' 'maximální' 'maximální'
# 25150 'Vzhledem' 'vzhledem' 'vzhledem'
# 25200 'Předehrávka' 'předehrávka' 'předehrávka'
# 25250 'Kdo' 'kdo' 'kdo'
# 25300 'Oslavy' 'oslava' 'Oslava'
# 25350 'Opoziční' 'opoziční' 'opoziční'
# 25400 'Jak' 'jak-3' 'jak-3'
# 25450 'V' 'v-1' 'v-1'
# 25500 'Vedoucí' 'vedoucí-2' 'vedoucí-2'
# 2834/2834 - 196s - loss: 0.0237 - val_accuracy: 0.9586 - 196s/epoch - 69ms/step
# Epoch 10/25
# 25550 'Stát' 'stát-1' 'stát-1'
# 25600 '(' '(' '('
# 25650 'Dlouhodobý' 'dlouhodobý' 'dlouhodobý'
# 25700 'Podle' 'podle-2' 'podle-2'
# 25750 'Memorandum' 'memorandum' 'memorandum'
# 25800 'jejich' 'jeho' 'jeho'
# 25850 'Co' 'co-1' 'co-1'
# 25900 'Masaryk' 'Masaryk' 'Masaryk'
# 25950 'Výsledky' 'výsledek' 'výsledek'
# 26000 'Po' 'po-1' 'po-1'
# 26050 'Oba' 'oba' 'oba'
# 26100 'Skutečnost' 'skutečnost' 'skutečnost'
# 26150 'Rekordní' 'rekordní' 'rekordní'
# 26200 '"' '"' '"'
# 26250 'Trvalo' 'trvat' 'trvat'
# 26300 'problémem' 'problém' 'problém'
# 26350 'Změnu' 'změna' 'změna'
# 26400 'Ruský' 'ruský' 'ruský'
# 26450 'Než' 'než-2' 'než-2'
# 26500 'Vzpomínání' 'vzpomínání' 'vzpomínání'
# 26550 'Dopadne' 'dopadnout' 'dopadnout'
# 26600 'Teď' 'teď' 'teď'
# 26650 '"' '"' '"'
# 26700 'RADAROVÝ' 'radarový' 'Radarová'
# 26750 'Po' 'po-1' 'po-1'
# 26800 'HOKEJOVOU' 'hokejový' 'hokejový'
# 26850 'Třetiny' 'třetina' 'třetina'
# 26900 'Vopat' 'Vopat' 'Vopat'
# 26950 'Č' 'český' 'český'
# 27000 'Program' 'program-1' 'program-1'
# 27050 'O' 'o-1' 'o-1'
# 27100 'Jinými' 'jiný' 'jiný'
# 27150 'ODU' 'ODU-88' 'ODU-88'
# 27200 'Byl' 'být' 'být'
# 27250 '-' '-' '-'
# 27300 'Etika' 'etika' 'Etika'
# 27350 'Schumpeterova' 'Schumpeterův' 'Schumpeterův'
# 27400 'Jelikož' 'jelikož' 'jelikož'
# 27450 'V' 'v-1' 'v-1'
# 27500 'Právě' 'právě-1' 'právě-1'
# 27550 'Snaha' 'snaha' 'snaha'
# 27600 '5355405185.5' '5355405185.5' '53515.1575'
# 27650 'Samostatný' 'samostatný' 'samostatný'
# 27700 'Zatímco' 'zatímco' 'zatímco'
# 27750 'Na' 'na-1' 'na-1'
# 27800 'Například' 'například' 'například'
# 27850 'Proti' 'proti-1' 'proti-1'
# 27900 '1' '1' '1'
# 27950 'ÖMV' 'ÖMV' 'ÖMV'
# 28000 'Finále' 'finále' 'finále'
# 28050 'Přímořská' 'přímořský' 'přímořský'
# 28100 'Varšava' 'Varšava' 'Varšava'
# 28150 'Sampras' 'Sampras' 'Sampras'
# 28200 '-' '-' '-'
# 28250 'K' 'k-1' 'k-1'
# 28300 'Kalkata' 'Kalkata' 'kalkata'
# 2834/2834 - 196s - loss: 0.0225 - val_accuracy: 0.9598 - 196s/epoch - 69ms/step
# Epoch 11/25
# 28350 'Lidé' 'lidé' 'lidé'
# 28400 'Podle' 'podle-2' 'podle-2'
# 28450 '"' '"' '"'
# 28500 'Pro' 'pro-1' 'pro-1'
# 28550 'Činitelé' 'činitel-1' 'činitel-1'
# 28600 'Z' 'z-1' 'z-1'
# 28650 'Francie' 'Francie' 'Francie'
# 28700 'Hudební' 'hudební' 'hudební'
# 28750 'Další' 'další' 'další'
# 28800 'Praha' 'Praha' 'Praha'
# 28850 'Projekt' 'projekt' 'projekt'
# 28900 'PŘÍPAD' 'případ' 'případ'
# 28950 'Tvrzení' 'tvrzení' 'tvrzení'
# 29000 'tenisovým' 'tenisový' 'tenisový'
# 29050 'Máme' 'mít' 'mít'
# 29100 'Opět' 'opět' 'opět'
# 29150 'Nejvyšší' 'vysoký' 'vysoký'
# 29200 'Ty' 'ten' 'ten'
# 29250 'Iluzorní' 'iluzorní' 'iluzorní'
# 29300 'Alexej' 'Alexej' 'Alexa'
# 29350 'Cenový' 'cenový' 'cenový'
# 29400 'Co' 'co-1' 'co-1'
# 29450 'Výše' 'výše' 'výše'
# 29500 'Zájem' 'zájem' 'zájem'
# 29550 'Pokud' 'pokud' 'pokud'
# 29600 '*' '*' '*'
# 29650 'V' 'v-1' 'v-1'
# 29700 'Voda' 'voda' 'voda'
# 29750 'Sprcha' 'sprcha' 'sprch'
# 29800 'Stejné' 'stejný' 'stejný'
# 29850 'Sociální' 'sociální' 'sociální'
# 29900 'Pomocným' 'pomocný' 'pomocný'
# 29950 'I' 'i-1' 'i-1'
# 30000 'Sleva' 'sleva' 'Sleva'
# 30050 '%' '%' '%'
# 30100 'Zdánlivě' 'zdánlivě' 'zdánlivě'
# 30150 'Zdůraznil' 'zdůraznit' 'zdůraznit'
# 30200 'Dvanáct' 'dvanáct' 'dvanáct'
# 30250 '(' '(' '('
# 30300 'Praha' 'Praha' 'Praha'
# 30350 'Kromě' 'kromě' 'kromě'
# 30400 'Kromě' 'kromě' 'kromě'
# 30450 'Na' 'na-1' 'na-1'
# 30500 'Míra' 'míra' 'míra'
# 30550 'Jako' 'jako-1' 'jako-1'
# 30600 'Město' 'město' 'město'
# 30650 'Dělníci' 'dělník' 'dělník'
# 30700 'Podle' 'podle-2' 'podle-2'
# 30750 'Ustanovení' 'ustanovení' 'ustanovení'
# 30800 'Žadatel' 'žadatel' 'žadatel'
# 30850 'Moby' 'Moby' 'Moby'
# 30900 'Krátce' 'krátce' 'krátce'
# 30950 'Ministerstvo' 'ministerstvo' 'ministerstvo'
# 31000 'Přitom' 'přitom' 'přitom'
# 31050 'Rozdíl' 'rozdíl' 'rozdíl'
# 31100 'Bez' 'bez-1' 'bez-1'
# 31150 'Lákala' 'lákat' 'Lákal'
# 2834/2834 - 195s - loss: 0.0217 - val_accuracy: 0.9594 - 195s/epoch - 69ms/step
# Epoch 12/25
# 31200 'Jste' 'být' 'být'
# 31250 'Možná' 'možná-1' 'možná-1'
# 31300 'Zdeno' 'Zdeno' 'Zdeno'
# 31350 'A' 'a-1' 'a-1'
# 31400 'Nový' 'nový' 'nový'
# 31450 'Ekologické' 'ekologický' 'ekologický'
# 31500 'Za' 'za' 'za'
# 31550 'Uvede' 'uvést' 'uvést'
# 31600 'Karel' 'Karel' 'Karel'
# 31650 'Ponechali' 'ponechat' 'ponechat'
# 31700 'Ty' 'ten' 'ten'
# 31750 'Když' 'když' 'když'
# 31800 'Antidumpingová' 'antidumpingový' 'antidumpingový'
# 31850 'Měl' 'mít' 'mít'
# 31900 'Chátrá' 'chátrat' 'chátrat'
# 31950 'Zejména' 'zejména-2' 'zejména-2'
# 32000 'Kostky' 'kostka' 'Kostka'
# 32050 'Foto' 'foto' 'foto'
# 32100 'Jiří' 'Jiří' 'Jiří'
# 32150 'McEnroe' 'McEnroe' 'McEnroe'
# 32200 'Český' 'český' 'český'
# 32250 'A' 'a-1' 'a-1'
# 32300 'Jsem' 'být' 'být'
# 32350 'Krátce' 'krátce' 'krátce'
# 32400 'To' 'ten' 'ten'
# 32450 'K' 'k-1' 'k-1'
# 32500 'Sdělil' 'sdělit' 'sdělit'
# 32550 'Ty' 'ten' 'ten'
# 32600 'Změnil' 'změnit' 'změnit'
# 32650 'Kolika' 'kolik' 'kolik'
# 32700 'Není' 'být' 'být'
# 32750 'Aby' 'aby' 'aby'
# 32800 'Jako' 'jako-1' 'jako-1'
# 32850 'To' 'ten' 'ten'
# 32900 'Jestli' 'jestli' 'jestli'
# 32950 'Nikdo' 'nikdo' 'nikdo'
# 33000 'Z' 'z-1' 'z-1'
# 33050 'Praha' 'Praha' 'Praha'
# 33100 'Praha' 'Praha' 'Praha'
# 33150 'Vláda' 'vláda' 'vláda'
# 33200 'Podle' 'podle-2' 'podle-2'
# 33250 'V' 'v-1' 'v-1'
# 33300 'Festival' 'festival' 'festival'
# 33350 'Svého' 'svůj-1' 'svůj-1'
# 33400 'Průměrné' 'průměrný' 'průměrný'
# 33450 'Některé' 'některý' 'některý'
# 33500 'Téhož' 'týž' 'týž'
# 33550 'Jednání' 'jednání' 'jednání'
# 33600 'Fond' 'fond' 'fond'
# 33650 'Řekněte' 'říci' 'říci'
# 33700 'Důvěřoval' 'důvěřovat' 'důvěřovat'
# 33750 'Občanské' 'občanský' 'občanský'
# 33800 'Lásky' 'láska' 'láska'
# 33850 'Most' 'Most-2' 'Most-2'
# 33900 'Před' 'před-1' 'před-1'
# 33950 'Soud' 'soud' 'soud'
# 34000 'Jak' 'jak-2' 'jak-3'
# 2834/2834 - 196s - loss: 0.0208 - val_accuracy: 0.9604 - 196s/epoch - 69ms/step
# Epoch 13/25
# 34050 'Oba' 'oba' 'oba'
# 34100 'Ačkoli' 'ačkoli' 'ačkoli'
# 34150 'Rusko' 'Rusko' 'Rusko'
# 34200 'Změnit' 'změnit' 'změnit'
# 34250 'Obrat' 'obrat-1' 'obrat-1'
# 34300 'Většina' 'většina' 'většina'
# 34350 'Janků' 'Janků' 'Jank'
# 34400 'Pominutelný' 'pominutelný' 'pominutelný'
# 34450 'Sofia' 'Sofie' 'Sofie'
# 34500 'Dvacátého' 'dvacátý' 'dvacátý'
# 34550 'Nepodmíněné' 'podmíněný' 'podmíněný'
# 34600 'Čeští' 'český' 'český'
# 34650 'Jak' 'jak-2' 'jak-3'
# 34700 'Vládne' 'vládnout' 'vládnout'
# 34750 'Ani' 'ani-1' 'ani-1'
# 34800 'Třeba' 'třeba-1' 'třeba-1'
# 34850 'Praha' 'Praha' 'Praha'
# 34900 'Pod' 'pod-1' 'pod-1'
# 34950 'Je' 'být' 'být'
# 35000 'nemohou' 'moci' 'moci'
# 35050 'Mezitím' 'mezitím' 'mezitím'
# 35100 'Musím' 'muset' 'muset'
# 35150 'A' 'a-1' 'a-1'
# 35200 'Socialismus' 'socialismus' 'socialismus'
# 35250 'Všude' 'všude' 'všude'
# 35300 'Světa' 'svět' 'svět'
# 35350 'A' 'a-1' 'a-1'
# 35400 'Manažer' 'manažer-1' 'manažer-1'
# 35450 'Takový' 'takový' 'takový'
# 35500 'Soud' 'soud' 'soud'
# 35550 '"' '"' '"'
# 35600 'Na' 'na-1' 'na-1'
# 35650 'Dříve' 'dříve' 'dříve'
# 35700 'Předkladatelé' 'předkladatel' 'předkladatel'
# 35750 'Vývozní' 'vývozní' 'vývozní'
# 35800 'Rozpočet' 'rozpočet' 'rozpočet'
# 35850 'Celkem' 'celkem' 'celkem'
# 35900 'Dnešní' 'dnešní' 'dnešní'
# 35950 'Proč' 'proč' 'proč'
# 36000 'Televize' 'televize' 'televize'
# 36050 'Thoresen' 'Thoresen' 'Thoresen'
# 36100 'Památce' 'památka' 'památka'
# 36150 'Jenže' 'jenže' 'jenže'
# 36200 'Československá' 'československý' 'československý'
# 36250 'V' 'v-1' 'v-1'
# 36300 'Z' 'z-1' 'z-1'
# 36350 'Nevelká' 'velký' 'velký'
# 36400 'Ale' 'ale' 'ale'
# 36450 'Tým' 'tým' 'tým'
# 36500 'Vzhledem' 'vzhledem' 'vzhledem'
# 36550 'Soud' 'soud' 'soud'
# 36600 'Inspektoři' 'inspektor' 'inspektor'
# 36650 'Je' 'být' 'být'
# 36700 'Ve' 'v-1' 'v-1'
# 36750 'Divácká' 'divácký' 'diváceký'
# 36800 'Pan' 'pan' 'pan'
# 2834/2834 - 194s - loss: 0.0202 - val_accuracy: 0.9569 - 194s/epoch - 69ms/step
# Epoch 14/25
# 36850 'Plzeň' 'Plzeň' 'Plzeň'
# 36900 'Banka' 'banka' 'banka'
# 36950 'Při' 'při-1' 'při-1'
# 37000 'Za' 'za' 'za'
# 37050 'V' 'v-1' 'v-1'
# 37100 'Předpokládá' 'předpokládat' 'předpokládat'
# 37150 '"' '"' '"'
# 37200 'Bratislava' 'Bratislava' 'Bratislava'
# 37250 '|' '|' '|'
# 37300 'Zkrácená' 'zkrácený' 'zkrácený'
# 37350 'První' 'první-1' 'první-1'
# 37400 'Nejdříve' 'dříve' 'dříve'
# 37450 'Druhá' 'druhý' 'druhý'
# 37500 'Znamená' 'znamenat' 'znamenat'
# 37550 'Přesto' 'přesto-1' 'přesto-1'
# 37600 'Při' 'při-1' 'při-1'
# 37650 'Do' 'do-1' 'do-1'
# 37700 'Abychom' 'aby' 'aby'
# 37750 'Pozvání' 'pozvání' 'pozvání'
# 37800 'Je' 'být' 'být'
# 37850 'Už' 'už-2' 'už-1'
# 37900 'Janáček' 'Janáček' 'Janáček'
# 37950 'Kdo' 'kdo' 'kdo'
# 38000 'Překvapit' 'překvapit' 'překvapit'
# 38050 'Nedávno' 'dávno-1' 'dávno-1'
# 38100 'Pak' 'pak' 'pak'
# 38150 'Zcela' 'zcela' 'zcela'
# 38200 'V' 'v-1' 'v-1'
# 38250 'Tento' 'tento' 'tento'
# 38300 'Pan' 'Pan-1' 'pan'
# 38350 'Zpočátku' 'zpočátku' 'zpočátku'
# 38400 '9' '9' '9'
# 38450 'Vbrzku' 'vbrzku' 'vbrzka'
# 38500 'Jako' 'jako-1' 'jako-1'
# 38550 'Co' 'co-1' 'co-1'
# 38600 'Siemens' 'Siemens-1' 'Siemens-1'
# 38650 'Základní' 'základní' 'základní'
# 38700 'Pozor' 'pozor-1' 'pozor-1'
# 38750 'Podle' 'podle-2' 'podle-2'
# 38800 'V' 'v-1' 'v-1'
# 38850 'Zdá' 'zdát' 'zdát'
# 38900 'Akcionáři' 'akcionář' 'akcionář'
# 38950 'Dále' 'dále-3' 'dále-3'
# 39000 'Za' 'za' 'za'
# 39050 'Jistě' 'jistě' 'jistě'
# 39100 'Sobotního' 'sobotní' 'sobotní'
# 39150 'V' 'v-1' 'v-1'
# 39200 'Tam' 'tam' 'tam'
# 39250 'Na' 'na-1' 'na-1'
# 39300 '"' '"' '"'
# 39350 'Kursy' 'kurs' 'Kurs'
# 39400 'Vyšetřování' 'vyšetřování' 'vyšetřování'
# 39450 'Ctí' 'čest' 'ctát'
# 39500 'Rumunská' 'rumunský' 'rumunský'
# 39550 'Svět' 'svět' 'svět'
# 39600 'S' 's-1' 'S-33'
# 39650 'Zástupce' 'zástupce' 'zástupce'
# 2834/2834 - 194s - loss: 0.0195 - val_accuracy: 0.9611 - 194s/epoch - 68ms/step
# Epoch 15/25
# 39700 'Týž' 'týž' 'týž'
# 39750 'Gibbon' 'Gibbon' 'Gibbon'
# 39800 'O' 'o-1' 'o-1'
# 39850 'Druhým' 'druhý' 'druhý'
# 39900 'Zavalitý' 'zavalitý' 'zavalitý'
# 39950 '"' '"' '"'
# 40000 'Tak' 'tak-3' 'tak-3'
# 40050 'Suková' 'Suková' 'Suková'
# 40100 'PLÁNY' 'plán' 'plán'
# 40150 'Doporučujeme' 'doporučovat' 'doporučovat'
# 40200 'Když' 'když' 'když'
# 40250 'Dokončený' 'dokončený' 'dokončený'
# 40300 'Bakalářství' 'bakalářství' 'bakalářství'
# 40350 'Podle' 'podle-2' 'podle-2'
# 40400 'V' 'v-1' 'v-1'
# 40450 'Jisté' 'jistý' 'jistý'
# 40500 'Informovala' 'informovat' 'informovat'
# 40550 'Situaci' 'situace' 'situace'
# 40600 'De' 'De-77' 'De-77'
# 40650 'Vykonávání' 'vykonávání' 'vykonávání'
# 40700 'Tato' 'tento' 'tento'
# 40750 'Problematické' 'problematický' 'problematický'
# 40800 '"' '"' '"'
# 40850 'Radost' 'radost' 'radost'
# 40900 'Rusko' 'Rusko' 'Rusko'
# 40950 'Teprve' 'teprve' 'teprve'
# 41000 'Ale' 'ale' 'ale'
# 41050 'Darja' 'Darja' 'Darja'
# 41100 'Jindy' 'jindy' 'Jindy'
# 41150 'Prezídium' 'prezídium' 'prezídium'
# 41200 'Vojenská' 'vojenský' 'vojenský'
# 41250 'Jižní' 'jižní' 'jižní'
# 41300 'Nabízíme' 'nabízet' 'nabízet'
# 41350 'Aby' 'aby' 'aby'
# 41400 'Poslední' 'poslední' 'poslední'
# 41450 'Jím' 'on-1' 'on-1'
# 41500 'Parlament' 'parlament' 'parlament'
# 41550 'Odbytišť' 'odbytiště' 'odbytiště'
# 41600 'K' 'k-1' 'k-1'
# 41650 'Ve' 'v-1' 'v-1'
# 41700 '58' '58' '58'
# 41750 'Úvěry' 'úvěr' 'úvěr'
# 41800 'Naopak' 'naopak-1' 'naopak-1'
# 41850 'Pacient' 'pacient' 'pacient'
# 41900 'MĚSTSKÉ' 'městský' 'městský'
# 41950 'Valašské' 'valašský' 'valašský'
# 42000 'Současné' 'současný' 'současný'
# 42050 'Jejich' 'jeho' 'jeho'
# 42100 'Na' 'na-1' 'na-1'
# 42150 'Druhou' 'druhý' 'druhý'
# 42200 'Adaptace' 'adaptace' 'adaptace'
# 42250 'Potlačily' 'potlačit' 'potlačit'
# 42300 'Tím' 'ten' 'ten'
# 42350 'Velké' 'velký' 'velký'
# 42400 'Nebo' 'nebo' 'nebo'
# 42450 'Věda' 'věda' 'věda'
# 42500 'Například' 'například' 'například'
# 2834/2834 - 193s - loss: 0.0192 - val_accuracy: 0.9624 - 193s/epoch - 68ms/step
# Epoch 16/25
# 42550 'Snímky' 'snímek' 'snímek'
# 42600 'Kresba' 'kresba' 'kresba'
# 42650 'Jiří' 'Jiří' 'Jiří'
# 42700 'Tam' 'tam' 'tam'
# 42750 'A' 'a-1' 'a-1'
# 42800 'Křehký' 'křehký' 'křehký'
# 42850 'Obě' 'oba' 'oba'
# 42900 'Vysoký' 'vysoký' 'vysoký'
# 42950 'Když' 'když' 'když'
# 43000 '(' '(' '('
# 43050 'Králíci' 'králík' 'Králík'
# 43100 'Přímé' 'přímý' 'přímý'
# 43150 'Lidstvo' 'lidstvo' 'lidstvo'
# 43200 'To' 'ten' 'ten'
# 43250 'Problém' 'problém' 'problém'
# 43300 'Zároveň' 'zároveň' 'zároveň'
# 43350 'To' 'ten' 'ten'
# 43400 'Je' 'být' 'být'
# 43450 'Ukazuje' 'ukazovat' 'ukazovat'
# 43500 'Teprve' 'teprve' 'teprve'
# 43550 'Vypravuje' 'vypravovat' 'vypravovat'
# 43600 'Patrně' 'patrně' 'patrně'
# 43650 'Někdo' 'někdo' 'někdo'
# 43700 'Maximální' 'maximální' 'maximální'
# 43750 'Vzhledem' 'vzhledem' 'vzhledem'
# 43800 'Předehrávka' 'předehrávka' 'předehrávka'
# 43850 'Kdo' 'kdo' 'kdo'
# 43900 'Oslavy' 'oslava' 'oslava'
# 43950 'Opoziční' 'opoziční' 'opoziční'
# 44000 'Jak' 'jak-3' 'jak-3'
# 44050 'V' 'v-1' 'v-1'
# 44100 'Vedoucí' 'vedoucí-2' 'vedoucí-2'
# 44150 'Stát' 'stát-1' 'stát-1'
# 44200 '(' '(' '('
# 44250 'Dlouhodobý' 'dlouhodobý' 'dlouhodobý'
# 44300 'Podle' 'podle-2' 'podle-2'
# 44350 'Memorandum' 'memorandum' 'memorandum'
# 44400 'jejich' 'jeho' 'jeho'
# 44450 'Co' 'co-1' 'co-1'
# 44500 'Masaryk' 'Masaryk' 'Masaryk'
# 44550 'Výsledky' 'výsledek' 'výsledek'
# 44600 'Po' 'po-1' 'po-1'
# 44650 'Oba' 'oba' 'oba'
# 44700 'Skutečnost' 'skutečnost' 'skutečnost'
# 44750 'Rekordní' 'rekordní' 'rekordní'
# 44800 '"' '"' '"'
# 44850 'Trvalo' 'trvat' 'trvat'
# 44900 'problémem' 'problém' 'problém'
# 44950 'Změnu' 'změna' 'změna'
# 45000 'Ruský' 'ruský' 'ruský'
# 45050 'Než' 'než-2' 'než-2'
# 45100 'Vzpomínání' 'vzpomínání' 'vzpomínání'
# 45150 'Dopadne' 'dopadnout' 'dopadnout'
# 45200 'Teď' 'teď' 'teď'
# 45250 '"' '"' '"'
# 45300 'RADAROVÝ' 'radarový' 'radarový'
# 2834/2834 - 192s - loss: 0.0185 - val_accuracy: 0.9612 - 192s/epoch - 68ms/step
# Epoch 17/25
# 45350 'Po' 'po-1' 'po-1'
# 45400 'HOKEJOVOU' 'hokejový' 'hokejový'
# 45450 'Třetiny' 'třetina' 'třetina'
# 45500 'Vopat' 'Vopat' 'Vopat'
# 45550 'Č' 'český' 'Č-33'
# 45600 'Program' 'program-1' 'program-1'
# 45650 'O' 'o-1' 'o-1'
# 45700 'Jinými' 'jiný' 'jiný'
# 45750 'ODU' 'ODU-88' 'ODU-88'
# 45800 'Byl' 'být' 'být'
# 45850 '-' '-' '-'
# 45900 'Etika' 'etika' 'etika'
# 45950 'Schumpeterova' 'Schumpeterův' 'Schumpeterův'
# 46000 'Jelikož' 'jelikož' 'jelikož'
# 46050 'V' 'v-1' 'v-1'
# 46100 'Právě' 'právě-1' 'právě-1'
# 46150 'Snaha' 'snaha' 'snaha'
# 46200 '5355405185.5' '5355405185.5' '5358531458.50'
# 46250 'Samostatný' 'samostatný' 'samostatný'
# 46300 'Zatímco' 'zatímco' 'zatímco'
# 46350 'Na' 'na-1' 'na-1'
# 46400 'Například' 'například' 'například'
# 46450 'Proti' 'proti-1' 'proti-1'
# 46500 '1' '1' '1'
# 46550 'ÖMV' 'ÖMV' 'ÖMV'
# 46600 'Finále' 'finále' 'finále'
# 46650 'Přímořská' 'přímořský' 'přímořský'
# 46700 'Varšava' 'Varšava' 'Varšava'
# 46750 'Sampras' 'Sampras' 'Sampras'
# 46800 '-' '-' '-'
# 46850 'K' 'k-1' 'k-1'
# 46900 'Kalkata' 'Kalkata' 'kalkat'
# 46950 'Lidé' 'lidé' 'lidé'
# 47000 'Podle' 'podle-2' 'podle-2'
# 47050 '"' '"' '"'
# 47100 'Pro' 'pro-1' 'pro-1'
# 47150 'Činitelé' 'činitel-1' 'činitel-1'
# 47200 'Z' 'z-1' 'z-1'
# 47250 'Francie' 'Francie' 'Francie'
# 47300 'Hudební' 'hudební' 'hudební'
# 47350 'Další' 'další' 'další'
# 47400 'Praha' 'Praha' 'Praha'
# 47450 'Projekt' 'projekt' 'projekt'
# 47500 'PŘÍPAD' 'případ' 'případ'
# 47550 'Tvrzení' 'tvrzení' 'tvrzení'
# 47600 'tenisovým' 'tenisový' 'tenisový'
# 47650 'Máme' 'mít' 'mít'
# 47700 'Opět' 'opět' 'opět'
# 47750 'Nejvyšší' 'vysoký' 'vysoký'
# 47800 'Ty' 'ten' 'ten'
# 47850 'Iluzorní' 'iluzorní' 'iluzorní'
# 47900 'Alexej' 'Alexej' 'Alexej'
# 47950 'Cenový' 'cenový' 'cenový'
# 48000 'Co' 'co-1' 'co-1'
# 48050 'Výše' 'výše' 'výše'
# 48100 'Zájem' 'zájem' 'zájem'
# 48150 'Pokud' 'pokud' 'pokud'
# 2834/2834 - 193s - loss: 0.0181 - val_accuracy: 0.9624 - 193s/epoch - 68ms/step
# Epoch 18/25
# 48200 '*' '*' '*'
# 48250 'V' 'v-1' 'v-1'
# 48300 'Voda' 'voda' 'voda'
# 48350 'Sprcha' 'sprcha' 'sprcha'
# 48400 'Stejné' 'stejný' 'stejný'
# 48450 'Sociální' 'sociální' 'sociální'
# 48500 'Pomocným' 'pomocný' 'pomocný'
# 48550 'I' 'i-1' 'i-1'
# 48600 'Sleva' 'sleva' 'sleva'
# 48650 '%' '%' '%'
# 48700 'Zdánlivě' 'zdánlivě' 'zdánlivě'
# 48750 'Zdůraznil' 'zdůraznit' 'zdůraznit'
# 48800 'Dvanáct' 'dvanáct' 'dvanáct'
# 48850 '(' '(' '('
# 48900 'Praha' 'Praha' 'Praha'
# 48950 'Kromě' 'kromě' 'kromě'
# 49000 'Kromě' 'kromě' 'kromě'
# 49050 'Na' 'na-1' 'na-1'
# 49100 'Míra' 'míra' 'míra'
# 49150 'Jako' 'jako-1' 'jako-1'
# 49200 'Město' 'město' 'město'
# 49250 'Dělníci' 'dělník' 'dělník'
# 49300 'Podle' 'podle-2' 'podle-2'
# 49350 'Ustanovení' 'ustanovení' 'ustanovení'
# 49400 'Žadatel' 'žadatel' 'žadatel'
# 49450 'Moby' 'Moby' 'Moby'
# 49500 'Krátce' 'krátce' 'krátce'
# 49550 'Ministerstvo' 'ministerstvo' 'ministerstvo'
# 49600 'Přitom' 'přitom' 'přitom'
# 49650 'Rozdíl' 'rozdíl' 'rozdíl'
# 49700 'Bez' 'bez-1' 'bez-1'
# 49750 'Lákala' 'lákat' 'Lákal'
# 49800 'Jste' 'být' 'být'
# 49850 'Možná' 'možná-1' 'možná-1'
# 49900 'Zdeno' 'Zdeno' 'Zdeno'
# 49950 'A' 'a-1' 'a-1'
# 50000 'Nový' 'nový' 'nový'
# 50050 'Ekologické' 'ekologický' 'ekologický'
# 50100 'Za' 'za' 'za'
# 50150 'Uvede' 'uvést' 'uvést'
# 50200 'Karel' 'Karel' 'Karel'
# 50250 'Ponechali' 'ponechat' 'ponechat'
# 50300 'Ty' 'ten' 'ten'
# 50350 'Když' 'když' 'když'
# 50400 'Antidumpingová' 'antidumpingový' 'antidmunipls'
# 50450 'Měl' 'mít' 'mít'
# 50500 'Chátrá' 'chátrat' 'chátrat'
# 50550 'Zejména' 'zejména-2' 'zejména-2'
# 50600 'Kostky' 'kostka' 'Kostka'
# 50650 'Foto' 'foto' 'foto'
# 50700 'Jiří' 'Jiří' 'Jiří'
# 50750 'McEnroe' 'McEnroe' 'McEnroe'
# 50800 'Český' 'český' 'český'
# 50850 'A' 'a-1' 'A-33'
# 50900 'Jsem' 'být' 'být'
# 50950 'Krátce' 'krátce' 'krátce'
# 51000 'To' 'ten' 'ten'
# 2834/2834 - 193s - loss: 0.0178 - val_accuracy: 0.9609 - 193s/epoch - 68ms/step
# Epoch 19/25
# 51050 'K' 'k-1' 'k-1'
# 51100 'Sdělil' 'sdělit' 'sdělit'
# 51150 'Ty' 'ten' 'ten'
# 51200 'Změnil' 'změnit' 'změnit'
# 51250 'Kolika' 'kolik' 'kolika'
# 51300 'Není' 'být' 'být'
# 51350 'Aby' 'aby' 'aby'
# 51400 'Jako' 'jako-1' 'jako-1'
# 51450 'To' 'ten' 'ten'
# 51500 'Jestli' 'jestli' 'jestli'
# 51550 'Nikdo' 'nikdo' 'nikdo'
# 51600 'Z' 'z-1' 'z-1'
# 51650 'Praha' 'Praha' 'Praha'
# 51700 'Praha' 'Praha' 'Praha'
# 51750 'Vláda' 'vláda' 'vláda'
# 51800 'Podle' 'podle-2' 'podle-2'
# 51850 'V' 'v-1' 'v-1'
# 51900 'Festival' 'festival' 'festival'
# 51950 'Svého' 'svůj-1' 'svůj-1'
# 52000 'Průměrné' 'průměrný' 'průměrný'
# 52050 'Některé' 'některý' 'některý'
# 52100 'Téhož' 'týž' 'týž'
# 52150 'Jednání' 'jednání' 'jednání'
# 52200 'Fond' 'fond' 'fond'
# 52250 'Řekněte' 'říci' 'říci'
# 52300 'Důvěřoval' 'důvěřovat' 'důvěřovat'
# 52350 'Občanské' 'občanský' 'občanský'
# 52400 'Lásky' 'láska' 'láska'
# 52450 'Most' 'Most-2' 'Most-2'
# 52500 'Před' 'před-1' 'před-1'
# 52550 'Soud' 'soud' 'soud'
# 52600 'Jak' 'jak-2' 'jak-3'
# 52650 'Oba' 'oba' 'oba'
# 52700 'Ačkoli' 'ačkoli' 'ačkoli'
# 52750 'Rusko' 'Rusko' 'Rusko'
# 52800 'Změnit' 'změnit' 'změnit'
# 52850 'Obrat' 'obrat-1' 'obrat-1'
# 52900 'Většina' 'většina' 'většina'
# 52950 'Janků' 'Janků' 'Janků'
# 53000 'Pominutelný' 'pominutelný' 'pominutelný'
# 53050 'Sofia' 'Sofie' 'Sofie'
# 53100 'Dvacátého' 'dvacátý' 'dvacátý'
# 53150 'Nepodmíněné' 'podmíněný' 'podmíněný'
# 53200 'Čeští' 'český' 'český'
# 53250 'Jak' 'jak-2' 'jak-3'
# 53300 'Vládne' 'vládnout' 'vládnout'
# 53350 'Ani' 'ani-1' 'ani-2'
# 53400 'Třeba' 'třeba-1' 'třeba-1'
# 53450 'Praha' 'Praha' 'Praha'
# 53500 'Pod' 'pod-1' 'pod-1'
# 53550 'Je' 'být' 'být'
# 53600 'nemohou' 'moci' 'moci'
# 53650 'Mezitím' 'mezitím' 'mezitím'
# 53700 'Musím' 'muset' 'muset'
# 53750 'A' 'a-1' 'a-1'
# 53800 'Socialismus' 'socialismus' 'socialismus'
# 2834/2834 - 193s - loss: 0.0177 - val_accuracy: 0.9622 - 193s/epoch - 68ms/step
# Epoch 20/25
# 53850 'Všude' 'všude' 'všude'
# 53900 'Světa' 'svět' 'svět'
# 53950 'A' 'a-1' 'a-1'
# 54000 'Manažer' 'manažer-1' 'manažer-1'
# 54050 'Takový' 'takový' 'takový'
# 54100 'Soud' 'soud' 'soud'
# 54150 '"' '"' '"'
# 54200 'Na' 'na-1' 'na-1'
# 54250 'Dříve' 'dříve' 'dříve'
# 54300 'Předkladatelé' 'předkladatel' 'předkladatel'
# 54350 'Vývozní' 'vývozní' 'vývozní'
# 54400 'Rozpočet' 'rozpočet' 'rozpočet'
# 54450 'Celkem' 'celkem' 'celkem'
# 54500 'Dnešní' 'dnešní' 'dnešní'
# 54550 'Proč' 'proč' 'proč'
# 54600 'Televize' 'televize' 'televize'
# 54650 'Thoresen' 'Thoresen' 'Thoresen'
# 54700 'Památce' 'památka' 'památka'
# 54750 'Jenže' 'jenže' 'jenže'
# 54800 'Československá' 'československý' 'československý'
# 54850 'V' 'v-1' 'v-1'
# 54900 'Z' 'z-1' 'z-1'
# 54950 'Nevelká' 'velký' 'velký'
# 55000 'Ale' 'ale' 'ale'
# 55050 'Tým' 'tým' 'tým'
# 55100 'Vzhledem' 'vzhledem' 'vzhledem'
# 55150 'Soud' 'soud' 'soud'
# 55200 'Inspektoři' 'inspektor' 'inspektor'
# 55250 'Je' 'být' 'být'
# 55300 'Ve' 'v-1' 'v-1'
# 55350 'Divácká' 'divácký' 'divácký'
# 55400 'Pan' 'pan' 'pan'
# 55450 'Plzeň' 'Plzeň' 'Plzeň'
# 55500 'Banka' 'banka' 'banka'
# 55550 'Při' 'při-1' 'při-1'
# 55600 'Za' 'za' 'za'
# 55650 'V' 'v-1' 'v-1'
# 55700 'Předpokládá' 'předpokládat' 'předpokládat'
# 55750 '"' '"' '"'
# 55800 'Bratislava' 'Bratislava' 'Bratislava'
# 55850 '|' '|' '|'
# 55900 'Zkrácená' 'zkrácený' 'zkrácený'
# 55950 'První' 'první-1' 'první-1'
# 56000 'Nejdříve' 'dříve' 'dříve'
# 56050 'Druhá' 'druhý' 'druhý'
# 56100 'Znamená' 'znamenat' 'znamenat'
# 56150 'Přesto' 'přesto-1' 'přesto-2'
# 56200 'Při' 'při-1' 'při-1'
# 56250 'Do' 'do-1' 'do-1'
# 56300 'Abychom' 'aby' 'aby'
# 56350 'Pozvání' 'pozvání' 'pozvání'
# 56400 'Je' 'být' 'být'
# 56450 'Už' 'už-2' 'už-1'
# 56500 'Janáček' 'Janáček' 'Janáček'
# 56550 'Kdo' 'kdo' 'kdo'
# 56600 'Překvapit' 'překvapit' 'překvapit'
# 56650 'Nedávno' 'dávno-1' 'dávno-1'
# 2834/2834 - 194s - loss: 0.0172 - val_accuracy: 0.9628 - 194s/epoch - 68ms/step
# Epoch 21/25
# 56700 'Pak' 'pak' 'pak'
# 56750 'Zcela' 'zcela' 'zcela'
# 56800 'V' 'v-1' 'v-1'
# 56850 'Tento' 'tento' 'tento'
# 56900 'Pan' 'Pan-1' 'pan'
# 56950 'Zpočátku' 'zpočátku' 'zpočátku'
# 57000 '9' '9' '9'
# 57050 'Vbrzku' 'vbrzku' 'vbrzku'
# 57100 'Jako' 'jako-1' 'jako-1'
# 57150 'Co' 'co-1' 'co-1'
# 57200 'Siemens' 'Siemens-1' 'Siemens-1'
# 57250 'Základní' 'základní' 'základní'
# 57300 'Pozor' 'pozor-1' 'pozor-1'
# 57350 'Podle' 'podle-2' 'podle-2'
# 57400 'V' 'v-1' 'v-1'
# 57450 'Zdá' 'zdát' 'zdát'
# 57500 'Akcionáři' 'akcionář' 'akcionář'
# 57550 'Dále' 'dále-3' 'dále-3'
# 57600 'Za' 'za' 'za'
# 57650 'Jistě' 'jistě' 'jistě'
# 57700 'Sobotního' 'sobotní' 'sobotní'
# 57750 'V' 'v-1' 'v-1'
# 57800 'Tam' 'tam' 'tam'
# 57850 'Na' 'na-1' 'na-1'
# 57900 '"' '"' '"'
# 57950 'Kursy' 'kurs' 'Kursy'
# 58000 'Vyšetřování' 'vyšetřování' 'vyšetřování'
# 58050 'Ctí' 'čest' 'ctít'
# 58100 'Rumunská' 'rumunský' 'rumunský'
# 58150 'Svět' 'svět' 'svět'
# 58200 'S' 's-1' 's-1'
# 58250 'Zástupce' 'zástupce' 'zástupce'
# 58300 'Týž' 'týž' 'týž'
# 58350 'Gibbon' 'Gibbon' 'Gibbon'
# 58400 'O' 'o-1' 'o-1'
# 58450 'Druhým' 'druhý' 'druhý'
# 58500 'Zavalitý' 'zavalitý' 'zavalitalý'
# 58550 '"' '"' '"'
# 58600 'Tak' 'tak-3' 'tak-3'
# 58650 'Suková' 'Suková' 'Suková'
# 58700 'PLÁNY' 'plán' 'plán'
# 58750 'Doporučujeme' 'doporučovat' 'doporučovat'
# 58800 'Když' 'když' 'když'
# 58850 'Dokončený' 'dokončený' 'dokončený'
# 58900 'Bakalářství' 'bakalářství' 'bakalářství'
# 58950 'Podle' 'podle-2' 'podle-2'
# 59000 'V' 'v-1' 'v-1'
# 59050 'Jisté' 'jistý' 'jistý'
# 59100 'Informovala' 'informovat' 'informovat'
# 59150 'Situaci' 'situace' 'situace'
# 59200 'De' 'De-77' 'De-77'
# 59250 'Vykonávání' 'vykonávání' 'vykonávání'
# 59300 'Tato' 'tento' 'tento'
# 59350 'Problematické' 'problematický' 'problematický'
# 59400 '"' '"' '"'
# 59450 'Radost' 'radost' 'radost'
# 59500 'Rusko' 'Rusko' 'Rusko'
# 2834/2834 - 193s - loss: 0.0169 - val_accuracy: 0.9620 - 193s/epoch - 68ms/step
# Epoch 22/25
# 59550 'Teprve' 'teprve' 'teprve'
# 59600 'Ale' 'ale' 'ale'
# 59650 'Darja' 'Darja' 'Darja'
# 59700 'Jindy' 'jindy' 'jindy'
# 59750 'Prezídium' 'prezídium' 'prezídium'
# 59800 'Vojenská' 'vojenský' 'vojenský'
# 59850 'Jižní' 'jižní' 'jižní'
# 59900 'Nabízíme' 'nabízet' 'nabízet'
# 59950 'Aby' 'aby' 'aby'
# 60000 'Poslední' 'poslední' 'poslední'
# 60050 'Jím' 'on-1' 'on-1'
# 60100 'Parlament' 'parlament' 'parlament'
# 60150 'Odbytišť' 'odbytiště' 'odbytiště'
# 60200 'K' 'k-1' 'k-1'
# 60250 'Ve' 'v-1' 'v-1'
# 60300 '58' '58' '58'
# 60350 'Úvěry' 'úvěr' 'úvěr'
# 60400 'Naopak' 'naopak-1' 'naopak-1'
# 60450 'Pacient' 'pacient' 'pacient'
# 60500 'MĚSTSKÉ' 'městský' 'městský'
# 60550 'Valašské' 'valašský' 'valašský'
# 60600 'Současné' 'současný' 'současný'
# 60650 'Jejich' 'jeho' 'jeho'
# 60700 'Na' 'na-1' 'na-1'
# 60750 'Druhou' 'druhý' 'druhý'
# 60800 'Adaptace' 'adaptace' 'adaptace'
# 60850 'Potlačily' 'potlačit' 'potlačit'
# 60900 'Tím' 'ten' 'ten'
# 60950 'Velké' 'velký' 'velký'
# 61000 'Nebo' 'nebo' 'nebo'
# 61050 'Věda' 'věda' 'věda'
# 61100 'Například' 'například' 'například'
# 61150 'Snímky' 'snímek' 'snímek'
# 61200 'Kresba' 'kresba' 'kresba'
# 61250 'Jiří' 'Jiří' 'Jiří'
# 61300 'Tam' 'tam' 'tam'
# 61350 'A' 'a-1' 'a-1'
# 61400 'Křehký' 'křehký' 'Křehký'
# 61450 'Obě' 'oba' 'oba'
# 61500 'Vysoký' 'vysoký' 'vysoký'
# 61550 'Když' 'když' 'když'
# 61600 '(' '(' '('
# 61650 'Králíci' 'králík' 'Králík'
# 61700 'Přímé' 'přímý' 'přímý'
# 61750 'Lidstvo' 'lidstvo' 'lidstvo'
# 61800 'To' 'ten' 'ten'
# 61850 'Problém' 'problém' 'problém'
# 61900 'Zároveň' 'zároveň' 'zároveň'
# 61950 'To' 'ten' 'ten'
# 62000 'Je' 'být' 'být'
# 62050 'Ukazuje' 'ukazovat' 'ukazovat'
# 62100 'Teprve' 'teprve' 'teprve'
# 62150 'Vypravuje' 'vypravovat' 'vypravovat'
# 62200 'Patrně' 'patrně' 'patrně'
# 62250 'Někdo' 'někdo' 'někdo'
# 62300 'Maximální' 'maximální' 'maximální'
# 2834/2834 - 194s - loss: 0.0166 - val_accuracy: 0.9628 - 194s/epoch - 68ms/step
# Epoch 23/25
# 62350 'Vzhledem' 'vzhledem' 'vzhledem'
# 62400 'Předehrávka' 'předehrávka' 'předehrávka'
# 62450 'Kdo' 'kdo' 'kdo'
# 62500 'Oslavy' 'oslava' 'oslava'
# 62550 'Opoziční' 'opoziční' 'opoziční'
# 62600 'Jak' 'jak-3' 'jak-3'
# 62650 'V' 'v-1' 'v-1'
# 62700 'Vedoucí' 'vedoucí-2' 'vedoucí'
# 62750 'Stát' 'stát-1' 'stát-1'
# 62800 '(' '(' '('
# 62850 'Dlouhodobý' 'dlouhodobý' 'dlouhodobý'
# 62900 'Podle' 'podle-2' 'podle-2'
# 62950 'Memorandum' 'memorandum' 'memorandum'
# 63000 'jejich' 'jeho' 'jeho'
# 63050 'Co' 'co-1' 'co-1'
# 63100 'Masaryk' 'Masaryk' 'Masaryk'
# 63150 'Výsledky' 'výsledek' 'výsledek'
# 63200 'Po' 'po-1' 'po-1'
# 63250 'Oba' 'oba' 'oba'
# 63300 'Skutečnost' 'skutečnost' 'skutečnost'
# 63350 'Rekordní' 'rekordní' 'rekordní'
# 63400 '"' '"' '"'
# 63450 'Trvalo' 'trvat' 'trvat'
# 63500 'problémem' 'problém' 'problém'
# 63550 'Změnu' 'změna' 'změna'
# 63600 'Ruský' 'ruský' 'ruský'
# 63650 'Než' 'než-2' 'než-2'
# 63700 'Vzpomínání' 'vzpomínání' 'vzpomínání'
# 63750 'Dopadne' 'dopadnout' 'dopadnout'
# 63800 'Teď' 'teď' 'teď'
# 63850 '"' '"' '"'
# 63900 'RADAROVÝ' 'radarový' 'radarový'
# 63950 'Po' 'po-1' 'po-1'
# 64000 'HOKEJOVOU' 'hokejový' 'hokejový'
# 64050 'Třetiny' 'třetina' 'třetina'
# 64100 'Vopat' 'Vopat' 'Vopat-77'
# 64150 'Č' 'český' 'český'
# 64200 'Program' 'program-1' 'program-1'
# 64250 'O' 'o-1' 'o-1'
# 64300 'Jinými' 'jiný' 'jiný'
# 64350 'ODU' 'ODU-88' 'od-1'
# 64400 'Byl' 'být' 'být'
# 64450 '-' '-' '-'
# 64500 'Etika' 'etika' 'etika'
# 64550 'Schumpeterova' 'Schumpeterův' 'Schumpeterův'
# 64600 'Jelikož' 'jelikož' 'jelikož'
# 64650 'V' 'v-1' 'v-1'
# 64700 'Právě' 'právě-1' 'právě-1'
# 64750 'Snaha' 'snaha' 'snaha'
# 64800 '5355405185.5' '5355405185.5' '535458541.58'
# 64850 'Samostatný' 'samostatný' 'samostatný'
# 64900 'Zatímco' 'zatímco' 'zatímco'
# 64950 'Na' 'na-1' 'na-1'
# 65000 'Například' 'například' 'například'
# 65050 'Proti' 'proti-1' 'proti-1'
# 65100 '1' '1' '1'
# 65150 'ÖMV' 'ÖMV' 'ÖMV'
# 2834/2834 - 194s - loss: 0.0163 - val_accuracy: 0.9631 - 194s/epoch - 68ms/step
# Epoch 24/25
# 65200 'Finále' 'finále' 'finále'
# 65250 'Přímořská' 'přímořský' 'přímořský'
# 65300 'Varšava' 'Varšava' 'Varšava'
# 65350 'Sampras' 'Sampras' 'Sampras'
# 65400 '-' '-' '-'
# 65450 'K' 'k-1' 'k-1'
# 65500 'Kalkata' 'Kalkata' 'Kalkata'
# 65550 'Lidé' 'lidé' 'lidé'
# 65600 'Podle' 'podle-2' 'podle-2'
# 65650 '"' '"' '"'
# 65700 'Pro' 'pro-1' 'pro-1'
# 65750 'Činitelé' 'činitel-1' 'činitel-1'
# 65800 'Z' 'z-1' 'z-1'
# 65850 'Francie' 'Francie' 'Francie'
# 65900 'Hudební' 'hudební' 'hudební'
# 65950 'Další' 'další' 'další'
# 66000 'Praha' 'Praha' 'Praha'
# 66050 'Projekt' 'projekt' 'projekt'
# 66100 'PŘÍPAD' 'případ' 'případ'
# 66150 'Tvrzení' 'tvrzení' 'tvrzení'
# 66200 'tenisovým' 'tenisový' 'tenisový'
# 66250 'Máme' 'mít' 'mít'
# 66300 'Opět' 'opět' 'opět'
# 66350 'Nejvyšší' 'vysoký' 'vysoký'
# 66400 'Ty' 'ten' 'ten'
# 66450 'Iluzorní' 'iluzorní' 'iluzorní'
# 66500 'Alexej' 'Alexej' 'Alexez'
# 66550 'Cenový' 'cenový' 'cenový'
# 66600 'Co' 'co-1' 'co-1'
# 66650 'Výše' 'výše' 'výše'
# 66700 'Zájem' 'zájem' 'zájem'
# 66750 'Pokud' 'pokud' 'pokud'
# 66800 '*' '*' '*'
# 66850 'V' 'v-1' 'v-1'
# 66900 'Voda' 'voda' 'voda'
# 66950 'Sprcha' 'sprcha' 'sprcha'
# 67000 'Stejné' 'stejný' 'stejný'
# 67050 'Sociální' 'sociální' 'sociální'
# 67100 'Pomocným' 'pomocný' 'pomocný'
# 67150 'I' 'i-1' 'i-1'
# 67200 'Sleva' 'sleva' 'sleva'
# 67250 '%' '%' '%'
# 67300 'Zdánlivě' 'zdánlivě' 'zdánlivě'
# 67350 'Zdůraznil' 'zdůraznit' 'zdůraznit'
# 67400 'Dvanáct' 'dvanáct' 'dvanáct'
# 67450 '(' '(' '('
# 67500 'Praha' 'Praha' 'Praha'
# 67550 'Kromě' 'kromě' 'kromě'
# 67600 'Kromě' 'kromě' 'kromě'
# 67650 'Na' 'na-1' 'na-1'
# 67700 'Míra' 'míra' 'míra'
# 67750 'Jako' 'jako-1' 'jako-1'
# 67800 'Město' 'město' 'město'
# 67850 'Dělníci' 'dělník' 'dělník'
# 67900 'Podle' 'podle-2' 'podle-2'
# 67950 'Ustanovení' 'ustanovení' 'ustanovení'
# 68000 'Žadatel' 'žadatel' 'žadatel'
# 2834/2834 - 192s - loss: 0.0161 - val_accuracy: 0.9634 - 192s/epoch - 68ms/step
# Epoch 25/25
# 68050 'Moby' 'Moby' 'Moby'
# 68100 'Krátce' 'krátce' 'krátce'
# 68150 'Ministerstvo' 'ministerstvo' 'ministerstvo'
# 68200 'Přitom' 'přitom' 'přitom'
# 68250 'Rozdíl' 'rozdíl' 'rozdíl'
# 68300 'Bez' 'bez-1' 'bez-1'
# 68350 'Lákala' 'lákat' 'Lákat'
# 68400 'Jste' 'být' 'být'
# 68450 'Možná' 'možná-1' 'možná-1'
# 68500 'Zdeno' 'Zdeno' 'Zdeno'
# 68550 'A' 'a-1' 'a-1'
# 68600 'Nový' 'nový' 'nový'
# 68650 'Ekologické' 'ekologický' 'ekologický'
# 68700 'Za' 'za' 'za'
# 68750 'Uvede' 'uvést' 'uvést'
# 68800 'Karel' 'Karel' 'Karel'
# 68850 'Ponechali' 'ponechat' 'ponechat'
# 68900 'Ty' 'ten' 'ten'
# 68950 'Když' 'když' 'když'
# 69000 'Antidumpingová' 'antidumpingový' 'antidumpingový'
# 69050 'Měl' 'mít' 'mít'
# 69100 'Chátrá' 'chátrat' 'chátrý'
# 69150 'Zejména' 'zejména-2' 'zejména-2'
# 69200 'Kostky' 'kostka' 'Kostka'
# 69250 'Foto' 'foto' 'foto'
# 69300 'Jiří' 'Jiří' 'Jiří'
# 69350 'McEnroe' 'McEnroe' 'McEnroe'
# 69400 'Český' 'český' 'český'
# 69450 'A' 'a-1' 'a-1'
# 69500 'Jsem' 'být' 'být'
# 69550 'Krátce' 'krátce' 'krátce'
# 69600 'To' 'ten' 'ten'
# 69650 'K' 'k-1' 'k-1'
# 69700 'Sdělil' 'sdělit' 'sdělit'
# 69750 'Ty' 'ten' 'ten'
# 69800 'Změnil' 'změnit' 'změnit'
# 69850 'Kolika' 'kolik' 'kolik'
# 69900 'Není' 'být' 'být'
# 69950 'Aby' 'aby' 'aby'
# 70000 'Jako' 'jako-1' 'jako-1'
# 70050 'To' 'ten' 'ten'
# 70100 'Jestli' 'jestli' 'jestli'
# 70150 'Nikdo' 'nikdo' 'nikdo'
# 70200 'Z' 'z-1' 'z-1'
# 70250 'Praha' 'Praha' 'Praha'
# 70300 'Praha' 'Praha' 'Praha'
# 70350 'Vláda' 'vláda' 'vláda'
# 70400 'Podle' 'podle-2' 'podle-2'
# 70450 'V' 'v-1' 'v-1'
# 70500 'Festival' 'festival' 'festival'
# 70550 'Svého' 'svůj-1' 'svůj-1'
# 70600 'Průměrné' 'průměrný' 'průměrný'
# 70650 'Některé' 'některý' 'některý'
# 70700 'Téhož' 'týž' 'týž'
# 70750 'Jednání' 'jednání' 'jednání'
# 70800 'Fond' 'fond' 'fond'
# 70850 'Řekněte' 'říci' 'říci'
# 2834/2834 - 193s - loss: 0.0159 - val_accuracy: 0.9611 - 193s/epoch - 68ms/step

# %%
parser = argparse.ArgumentParser()
parser.add_argument("--batch_size", default=128, type=int, help="Batch size.")
parser.add_argument("--cle_dim", default=192, type=int, help="CLE embedding dimension.")
parser.add_argument("--epochs", default=10, type=int, help="Number of epochs.")
parser.add_argument("--max_sentences", default=None, type=int, help="Maximum number of sentences to load.")
parser.add_argument("--recodex", default=False, action="store_true", help="Evaluation in ReCodEx.")
parser.add_argument("--rnn_dim", default=192, type=int, help="RNN cell dimension.")
parser.add_argument("--seed", default=42, type=int, help="Random seed.")
parser.add_argument("--threads", default=0, type=int, help="Maximum number of threads to use.")

args = parser.parse_args([] if "__file__" not in globals() else None)
print(args)
main(args)
# Out:
# Namespace(batch_size=128, cle_dim=192, epochs=10, max_sentences=None, recodex=False, rnn_dim=192, seed=42, threads=0)
# Epoch 1/10
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("Adam/gradients/concat_1:0", shape=(None,), dtype=int32), values=Tensor("Adam/gradients/concat:0", shape=(None, 192), dtype=float32), dense_shape=Tensor("gradient_tape/model_6/bidirectional_6/forward_gru_6/RaggedToTensor/Shape:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# 50 '|' '|' ''
# 100 'Druhá' 'druhý' 'prod'
# 150 'Do' 'do-1' 'od-1'
# 200 'Už' 'už-2' 'že-1'
# 250 'Nedávno' 'dávno-1' 'dávní'
# 300 'Tento' 'tento' 'tento'
# 350 'Vbrzku' 'vbrzku' 'výrzk'
# 400 'Základní' 'základní' 'základní'
# 450 'Zdá' 'zdát' 'zdát'
# 500 'Jistě' 'jistě' 'Jistě'
# 550 'Na' 'na-1' 'na-1'
# 600 'Ctí' 'čest' 'tít'
# 650 'Zástupce' 'zástupce' 'zástupce'
# 700 'Druhým' 'druhý' 'druhý'
# 709/709 - 88s - loss: 0.8805 - val_accuracy: 0.8633 - 88s/epoch - 124ms/step
# Epoch 2/10
# 750 'Suková' 'Suková' 'Sukovat'
# 800 'Dokončený' 'dokončený' 'dokončený'
# 850 'Jisté' 'jistý' 'jistý'
# 900 'Vykonávání' 'vykonávání' 'vykonávání'
# 950 'Radost' 'radost' 'radost'
# 1000 'Darja' 'Darja' 'darja'
# 1050 'Jižní' 'jižní' 'jižní'
# 1100 'Jím' 'on-1' 'jít'
# 1150 'Ve' 'v-1' 'v-1'
# 1200 'Pacient' 'pacient' 'pacient'
# 1250 'Jejich' 'jeho' 'jeho'
# 1300 'Potlačily' 'potlačit' 'potlačit'
# 1350 'Věda' 'věda' 'věda'
# 1400 'Jiří' 'Jiří' 'Jiří'
# 709/709 - 79s - loss: 0.0939 - val_accuracy: 0.9251 - 79s/epoch - 112ms/step
# Epoch 3/10
# 1450 'Obě' 'oba' 'oba'
# 1500 'Králíci' 'králík' 'Králík'
# 1550 'Problém' 'problém' 'problém'
# 1600 'Ukazuje' 'ukazovat' 'ukazovat'
# 1650 'Někdo' 'někdo' 'někdo'
# 1700 'Kdo' 'kdo' 'kdo'
# 1750 'V' 'v-1' 'v-1'
# 1800 'Dlouhodobý' 'dlouhodobý' 'dlouhodobý'
# 1850 'Co' 'co-1' 'co-1'
# 1900 'Oba' 'oba' 'oba'
# 1950 'Trvalo' 'trvat' 'trvat'
# 2000 'Než' 'než-2' 'než-2'
# 2050 '"' '"' '"'
# 2100 'Třetiny' 'třetina' 'třetina'
# 709/709 - 79s - loss: 0.0538 - val_accuracy: 0.9438 - 79s/epoch - 111ms/step
# Epoch 4/10
# 2150 'O' 'o-1' 'o-1'
# 2200 '-' '-' '-'
# 2250 'V' 'v-1' 'v-1'
# 2300 'Samostatný' 'samostatný' 'samostatný'
# 2350 'Proti' 'proti-1' 'proti-1'
# 2400 'Přímořská' 'přímořský' 'přímořský'
# 2450 'K' 'k-1' 'k-1'
# 2500 '"' '"' '"'
# 2550 'Francie' 'Francie' 'Francie'
# 2600 'Projekt' 'projekt' 'projekt'
# 2650 'Máme' 'mít' 'mít'
# 2700 'Iluzorní' 'iluzorní' 'Iluzorní'
# 2750 'Výše' 'výše' 'výše'
# 2800 'V' 'v-1' 'v-1'
# 709/709 - 79s - loss: 0.0395 - val_accuracy: 0.9511 - 79s/epoch - 111ms/step
# Epoch 5/10
# 2850 'Sociální' 'sociální' 'sociální'
# 2900 '%' '%' '%'
# 2950 '(' '(' '('
# 3000 'Na' 'na-1' 'na-1'
# 3050 'Dělníci' 'dělník' 'dělník'
# 3100 'Moby' 'Moby' 'Moby'
# 3150 'Rozdíl' 'rozdíl' 'rozdíl'
# 3200 'Možná' 'možná-1' 'možná-1'
# 3250 'Ekologické' 'ekologický' 'ekologický'
# 3300 'Ponechali' 'ponechat' 'ponechat'
# 3350 'Měl' 'mít' 'mít'
# 3400 'Foto' 'foto' 'foto'
# 3450 'A' 'a-1' 'a-1'
# 3500 'K' 'k-1' 'k-1'
# 709/709 - 79s - loss: 0.0320 - val_accuracy: 0.9535 - 79s/epoch - 111ms/step
# Epoch 6/10
# 3550 'Kolika' 'kolik' 'kolik'
# 3600 'To' 'ten' 'ten'
# 3650 'Praha' 'Praha' 'Praha'
# 3700 'V' 'v-1' 'v-1'
# 3750 'Některé' 'některý' 'některý'
# 3800 'Řekněte' 'říci' 'říci'
# 3850 'Most' 'Most-2' 'Most-2'
# 3900 'Oba' 'oba' 'oba'
# 3950 'Obrat' 'obrat-1' 'obrat-1'
# 4000 'Sofia' 'Sofie' 'Sofie'
# 4050 'Jak' 'jak-2' 'jak-3'
# 4100 'Praha' 'Praha' 'Praha'
# 4150 'Mezitím' 'mezitím' 'mezitím'
# 4200 'Všude' 'všude' 'všude'
# 4250 'Takový' 'takový' 'takový'
# 709/709 - 79s - loss: 0.0272 - val_accuracy: 0.9572 - 79s/epoch - 111ms/step
# Epoch 7/10
# 4300 'Dříve' 'dříve' 'dříve'
# 4350 'Celkem' 'celkem' 'celkem'
# 4400 'Thoresen' 'Thoresen' 'Thoresnout'
# 4450 'V' 'v-1' 'v-1'
# 4500 'Tým' 'tým' 'tým'
# 4550 'Je' 'být' 'být'
# 4600 'Plzeň' 'Plzeň' 'Plzeň'
# 4650 'V' 'v-1' 'v-1'
# 4700 '|' '|' '|'
# 4750 'Druhá' 'druhý' 'druhý'
# 4800 'Do' 'do-1' 'do-1'
# 4850 'Už' 'už-2' 'už-1'
# 4900 'Nedávno' 'dávno-1' 'dávno-1'
# 4950 'Tento' 'tento' 'tento'
# 709/709 - 78s - loss: 0.0241 - val_accuracy: 0.9600 - 78s/epoch - 110ms/step
# Epoch 8/10
# 5000 'Vbrzku' 'vbrzku' 'vbrzku'
# 5050 'Základní' 'základní' 'základní'
# 5100 'Zdá' 'zdát' 'zdát'
# 5150 'Jistě' 'jistě' 'jistě'
# 5200 'Na' 'na-1' 'na-1'
# 5250 'Ctí' 'čest' 'ctít'
# 5300 'Zástupce' 'zástupce' 'zástupce'
# 5350 'Druhým' 'druhý' 'druhý'
# 5400 'Suková' 'Suková' 'Suková'
# 5450 'Dokončený' 'dokončený' 'dokončený'
# 5500 'Jisté' 'jistý' 'jistý'
# 5550 'Vykonávání' 'vykonávání' 'vykonávání'
# 5600 'Radost' 'radost' 'radost'
# 5650 'Darja' 'Darja' 'darja'
# 709/709 - 77s - loss: 0.0217 - val_accuracy: 0.9610 - 77s/epoch - 109ms/step
# Epoch 9/10
# 5700 'Jižní' 'jižní' 'jižní'
# 5750 'Jím' 'on-1' 'jíst'
# 5800 'Ve' 'v-1' 'v-1'
# 5850 'Pacient' 'pacient' 'pacient'
# 5900 'Jejich' 'jeho' 'jeho'
# 5950 'Potlačily' 'potlačit' 'potlačit'
# 6000 'Věda' 'věda' 'věda'
# 6050 'Jiří' 'Jiří' 'Jiří'
# 6100 'Obě' 'oba' 'oba'
# 6150 'Králíci' 'králík' 'králíc'
# 6200 'Problém' 'problém' 'problém'
# 6250 'Ukazuje' 'ukazovat' 'ukazovat'
# 6300 'Někdo' 'někdo' 'někdo'
# 6350 'Kdo' 'kdo' 'kdo'
# 709/709 - 78s - loss: 0.0198 - val_accuracy: 0.9611 - 78s/epoch - 109ms/step
# Epoch 10/10
# 6400 'V' 'v-1' 'v-1'
# 6450 'Dlouhodobý' 'dlouhodobý' 'dlouhodobý'
# 6500 'Co' 'co-1' 'co-1'
# 6550 'Oba' 'oba' 'oba'
# 6600 'Trvalo' 'trvat' 'trvat'
# 6650 'Než' 'než-2' 'než-2'
# 6700 '"' '"' '"'
# 6750 'Třetiny' 'třetina' 'třetina'
# 6800 'O' 'o-1' 'o-1'
# 6850 '-' '-' '-'
# 6900 'V' 'v-1' 'v-1'
# 6950 'Samostatný' 'samostatný' 'samostatný'
# 7000 'Proti' 'proti-1' 'proti-1'
# 7050 'Přímořská' 'přímořský' 'přímořský'
# 709/709 - 78s - loss: 0.0183 - val_accuracy: 0.9646 - 78s/epoch - 109ms/step

# %%
parser = argparse.ArgumentParser()
parser.add_argument("--batch_size", default=128, type=int, help="Batch size.")
parser.add_argument("--cle_dim", default=192, type=int, help="CLE embedding dimension.")
parser.add_argument("--epochs", default=25, type=int, help="Number of epochs.")
parser.add_argument("--max_sentences", default=None, type=int, help="Maximum number of sentences to load.")
parser.add_argument("--recodex", default=False, action="store_true", help="Evaluation in ReCodEx.")
parser.add_argument("--rnn_dim", default=192, type=int, help="RNN cell dimension.")
parser.add_argument("--seed", default=42, type=int, help="Random seed.")
parser.add_argument("--threads", default=0, type=int, help="Maximum number of threads to use.")

args = parser.parse_args([] if "__file__" not in globals() else None)
print(args)
main(args)
# Out:
# Namespace(batch_size=128, cle_dim=192, epochs=25, max_sentences=None, recodex=False, rnn_dim=192, seed=42, threads=0)
# Epoch 1/25
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/indexed_slices.py:446: UserWarning: Converting sparse IndexedSlices(IndexedSlices(indices=Tensor("Adam/gradients/concat_1:0", shape=(None,), dtype=int32), values=Tensor("Adam/gradients/concat:0", shape=(None, 192), dtype=float32), dense_shape=Tensor("gradient_tape/model_7/bidirectional_7/forward_gru_7/RaggedToTensor/Shape:0", shape=(2,), dtype=int32))) to a dense Tensor of unknown shape. This may consume a large amount of memory.
#   "shape. This may consume a large amount of memory." % value)
# 50 '|' '|' ''
# 100 'Druhá' 'druhý' 'prod'
# 150 'Do' 'do-1' 'od-1'
# 200 'Už' 'už-2' 'že-1'
# 250 'Nedávno' 'dávno-1' 'dávní'
# 300 'Tento' 'tento' 'tento'
# 350 'Vbrzku' 'vbrzku' 'výrzk'
# 400 'Základní' 'základní' 'základní'
# 450 'Zdá' 'zdát' 'zdát'
# 500 'Jistě' 'jistě' 'Jistě'
# 550 'Na' 'na-1' 'na-1'
# 600 'Ctí' 'čest' 'tít'
# 650 'Zástupce' 'zástupce' 'zástupce'
# 700 'Druhým' 'druhý' 'druhý'
# 709/709 - 89s - loss: 0.8805 - val_accuracy: 0.8632 - 89s/epoch - 126ms/step
# Epoch 2/25
# 750 'Suková' 'Suková' 'Sukovat'
# 800 'Dokončený' 'dokončený' 'dokončený'
# 850 'Jisté' 'jistý' 'jistý'
# 900 'Vykonávání' 'vykonávání' 'vykonávání'
# 950 'Radost' 'radost' 'radost'
# 1000 'Darja' 'Darja' 'darja'
# 1050 'Jižní' 'jižní' 'jižní'
# 1100 'Jím' 'on-1' 'jít'
# 1150 'Ve' 'v-1' 'v-1'
# 1200 'Pacient' 'pacient' 'pacient'
# 1250 'Jejich' 'jeho' 'jeho'
# 1300 'Potlačily' 'potlačit' 'potlačit'
# 1350 'Věda' 'věda' 'věda'
# 1400 'Jiří' 'Jiří' 'Jiří'
# 709/709 - 80s - loss: 0.0939 - val_accuracy: 0.9250 - 80s/epoch - 113ms/step
# Epoch 3/25
# 1450 'Obě' 'oba' 'oba'
# 1500 'Králíci' 'králík' 'Králík'
# 1550 'Problém' 'problém' 'problém'
# 1600 'Ukazuje' 'ukazovat' 'ukazovat'
# 1650 'Někdo' 'někdo' 'někdo'
# 1700 'Kdo' 'kdo' 'kdo'
# 1750 'V' 'v-1' 'v-1'
# 1800 'Dlouhodobý' 'dlouhodobý' 'dlouhodobý'
# 1850 'Co' 'co-1' 'co-1'
# 1900 'Oba' 'oba' 'oba'
# 1950 'Trvalo' 'trvat' 'trvat'
# 2000 'Než' 'než-2' 'než-2'
# 2050 '"' '"' '"'
# 2100 'Třetiny' 'třetina' 'třetina'
# 709/709 - 80s - loss: 0.0538 - val_accuracy: 0.9438 - 80s/epoch - 113ms/step
# Epoch 4/25
# 2150 'O' 'o-1' 'o-1'
# 2200 '-' '-' '-'
# 2250 'V' 'v-1' 'v-1'
# 2300 'Samostatný' 'samostatný' 'samostatný'
# 2350 'Proti' 'proti-1' 'proti-1'
# 2400 'Přímořská' 'přímořský' 'přímořský'
# 2450 'K' 'k-1' 'k-1'
# 2500 '"' '"' '"'
# 2550 'Francie' 'Francie' 'Francie'
# 2600 'Projekt' 'projekt' 'projekt'
# 2650 'Máme' 'mít' 'mít'
# 2700 'Iluzorní' 'iluzorní' 'Iluzorní'
# 2750 'Výše' 'výše' 'výše'
# 2800 'V' 'v-1' 'v-1'
# 709/709 - 80s - loss: 0.0395 - val_accuracy: 0.9510 - 80s/epoch - 113ms/step
# Epoch 5/25
# 2850 'Sociální' 'sociální' 'sociální'
# 2900 '%' '%' '%'
# 2950 '(' '(' '('
# 3000 'Na' 'na-1' 'na-1'
# 3050 'Dělníci' 'dělník' 'dělník'
# 3100 'Moby' 'Moby' 'Moby'
# 3150 'Rozdíl' 'rozdíl' 'rozdíl'
# 3200 'Možná' 'možná-1' 'možná-1'
# 3250 'Ekologické' 'ekologický' 'ekologický'
# 3300 'Ponechali' 'ponechat' 'ponechat'
# 3350 'Měl' 'mít' 'mít'
# 3400 'Foto' 'foto' 'foto'
# 3450 'A' 'a-1' 'a-1'
# 3500 'K' 'k-1' 'k-1'
# 709/709 - 80s - loss: 0.0320 - val_accuracy: 0.9537 - 80s/epoch - 113ms/step
# Epoch 6/25
# 3550 'Kolika' 'kolik' 'kolik'
# 3600 'To' 'ten' 'ten'
# 3650 'Praha' 'Praha' 'Praha'
# 3700 'V' 'v-1' 'v-1'
# 3750 'Některé' 'některý' 'některý'
# 3800 'Řekněte' 'říci' 'říci'
# 3850 'Most' 'Most-2' 'Most-2'
# 3900 'Oba' 'oba' 'oba'
# 3950 'Obrat' 'obrat-1' 'obrat-1'
# 4000 'Sofia' 'Sofie' 'Sofie'
# 4050 'Jak' 'jak-2' 'jak-3'
# 4100 'Praha' 'Praha' 'Praha'
# 4150 'Mezitím' 'mezitím' 'mezitím'
# 4200 'Všude' 'všude' 'všude'
# 4250 'Takový' 'takový' 'takový'
# 709/709 - 79s - loss: 0.0273 - val_accuracy: 0.9575 - 79s/epoch - 111ms/step
# Epoch 7/25
# 4300 'Dříve' 'dříve' 'dříve'
# 4350 'Celkem' 'celkem' 'celkem'
# 4400 'Thoresen' 'Thoresen' 'Thoresen'
# 4450 'V' 'v-1' 'v-1'
# 4500 'Tým' 'tým' 'tým'
# 4550 'Je' 'být' 'být'
# 4600 'Plzeň' 'Plzeň' 'Plzeň'
# 4650 'V' 'v-1' 'v-1'
# 4700 '|' '|' '|'
# 4750 'Druhá' 'druhý' 'druhý'
# 4800 'Do' 'do-1' 'do-1'
# 4850 'Už' 'už-2' 'už-1'
# 4900 'Nedávno' 'dávno-1' 'dávno-1'
# 4950 'Tento' 'tento' 'tento'
# 709/709 - 79s - loss: 0.0242 - val_accuracy: 0.9592 - 79s/epoch - 112ms/step
# Epoch 8/25
# 5000 'Vbrzku' 'vbrzku' 'vbrzku'
# 5050 'Základní' 'základní' 'základní'
# 5100 'Zdá' 'zdát' 'zdát'
# 5150 'Jistě' 'jistě' 'jistě'
# 5200 'Na' 'na-1' 'na-1'
# 5250 'Ctí' 'čest' 'ctít'
# 5300 'Zástupce' 'zástupce' 'zástupce'
# 5350 'Druhým' 'druhý' 'druhý'
# 5400 'Suková' 'Suková' 'Suková'
# 5450 'Dokončený' 'dokončený' 'dokončený'
# 5500 'Jisté' 'jistý' 'jistý'
# 5550 'Vykonávání' 'vykonávání' 'vykonávání'
# 5600 'Radost' 'radost' 'radost'
# 5650 'Darja' 'Darja' 'darja'
# 709/709 - 79s - loss: 0.0217 - val_accuracy: 0.9612 - 79s/epoch - 112ms/step
# Epoch 9/25
# 5700 'Jižní' 'jižní' 'jižní'
# 5750 'Jím' 'on-1' 'jíst'
# 5800 'Ve' 'v-1' 'v-1'
# 5850 'Pacient' 'pacient' 'pacient'
# 5900 'Jejich' 'jeho' 'jeho'
# 5950 'Potlačily' 'potlačit' 'potlačit'
# 6000 'Věda' 'věda' 'věda'
# 6050 'Jiří' 'Jiří' 'Jiří'
# 6100 'Obě' 'oba' 'oba'
# 6150 'Králíci' 'králík' 'králíc'
# 6200 'Problém' 'problém' 'problém'
# 6250 'Ukazuje' 'ukazovat' 'ukazovat'
# 6300 'Někdo' 'někdo' 'někdo'
# 6350 'Kdo' 'kdo' 'kdo'
# 709/709 - 80s - loss: 0.0198 - val_accuracy: 0.9614 - 80s/epoch - 113ms/step
# Epoch 10/25
# 6400 'V' 'v-1' 'v-1'
# 6450 'Dlouhodobý' 'dlouhodobý' 'dlouhodobý'
# 6500 'Co' 'co-1' 'co-1'
# 6550 'Oba' 'oba' 'oba'
# 6600 'Trvalo' 'trvat' 'trvat'
# 6650 'Než' 'než-2' 'než-2'
# 6700 '"' '"' '"'
# 6750 'Třetiny' 'třetina' 'třetina'
# 6800 'O' 'o-1' 'o-1'
# 6850 '-' '-' '-'
# 6900 'V' 'v-1' 'v-1'
# 6950 'Samostatný' 'samostatný' 'samostatný'
# 7000 'Proti' 'proti-1' 'proti-1'
# 7050 'Přímořská' 'přímořský' 'přímořský'
# 709/709 - 79s - loss: 0.0183 - val_accuracy: 0.9646 - 79s/epoch - 112ms/step
# Epoch 11/25
# 7100 'K' 'k-1' 'k-1'
# 7150 '"' '"' '"'
# 7200 'Francie' 'Francie' 'Francie'
# 7250 'Projekt' 'projekt' 'projekt'
# 7300 'Máme' 'mít' 'mít'
# 7350 'Iluzorní' 'iluzorní' 'iluzorní'
# 7400 'Výše' 'výše' 'výše'
# 7450 'V' 'v-1' 'v-1'
# 7500 'Sociální' 'sociální' 'sociální'
# 7550 '%' '%' '%'
# 7600 '(' '(' '('
# 7650 'Na' 'na-1' 'na-1'
# 7700 'Dělníci' 'dělník' 'dělník'
# 7750 'Moby' 'Moby' 'Moby'
# 709/709 - 79s - loss: 0.0171 - val_accuracy: 0.9651 - 79s/epoch - 111ms/step
# Epoch 12/25
# 7800 'Rozdíl' 'rozdíl' 'rozdíl'
# 7850 'Možná' 'možná-1' 'možná-1'
# 7900 'Ekologické' 'ekologický' 'ekologický'
# 7950 'Ponechali' 'ponechat' 'ponechat'
# 8000 'Měl' 'mít' 'mít'
# 8050 'Foto' 'foto' 'foto'
# 8100 'A' 'a-1' 'a-1'
# 8150 'K' 'k-1' 'k-1'
# 8200 'Kolika' 'kolik' 'kolika'
# 8250 'To' 'ten' 'ten'
# 8300 'Praha' 'Praha' 'Praha'
# 8350 'V' 'v-1' 'v-1'
# 8400 'Některé' 'některý' 'některý'
# 8450 'Řekněte' 'říci' 'říci'
# 8500 'Most' 'Most-2' 'Most-2'
# 709/709 - 79s - loss: 0.0161 - val_accuracy: 0.9647 - 79s/epoch - 111ms/step
# Epoch 13/25
# 8550 'Oba' 'oba' 'oba'
# 8600 'Obrat' 'obrat-1' 'obrat-1'
# 8650 'Sofia' 'Sofie' 'Sofie'
# 8700 'Jak' 'jak-2' 'jak-3'
# 8750 'Praha' 'Praha' 'Praha'
# 8800 'Mezitím' 'mezitím' 'mezitím'
# 8850 'Všude' 'všude' 'všude'
# 8900 'Takový' 'takový' 'takový'
# 8950 'Dříve' 'dříve' 'dříve'
# 9000 'Celkem' 'celkem' 'celkem'
# 9050 'Thoresen' 'Thoresen' 'Thoresen'
# 9100 'V' 'v-1' 'v-1'
# 9150 'Tým' 'tým' 'tým'
# 9200 'Je' 'být' 'být'
# 709/709 - 79s - loss: 0.0155 - val_accuracy: 0.9642 - 79s/epoch - 112ms/step
# Epoch 14/25
# 9250 'Plzeň' 'Plzeň' 'Plzeň'
# 9300 'V' 'v-1' 'v-1'
# 9350 '|' '|' '|'
# 9400 'Druhá' 'druhý' 'druhý'
# 9450 'Do' 'do-1' 'do-1'
# 9500 'Už' 'už-2' 'už-1'
# 9550 'Nedávno' 'dávno-1' 'dávno-1'
# 9600 'Tento' 'tento' 'tento'
# 9650 'Vbrzku' 'vbrzku' 'vbrzku'
# 9700 'Základní' 'základní' 'základní'
# 9750 'Zdá' 'zdát' 'zdát'
# 9800 'Jistě' 'jistě' 'jistě'
# 9850 'Na' 'na-1' 'na-1'
# 9900 'Ctí' 'čest' 'Ctí-1'
# 709/709 - 78s - loss: 0.0146 - val_accuracy: 0.9647 - 78s/epoch - 111ms/step
# Epoch 15/25
# 9950 'Zástupce' 'zástupce' 'zástupce'
# 10000 'Druhým' 'druhý' 'druhý'
# 10050 'Suková' 'Suková' 'Suková'
# 10100 'Dokončený' 'dokončený' 'dokončený'
# 10150 'Jisté' 'jistý' 'jistý'
# 10200 'Vykonávání' 'vykonávání' 'vykonávání'
# 10250 'Radost' 'radost' 'radost'
# 10300 'Darja' 'Darja' 'Darja'
# 10350 'Jižní' 'jižní' 'jižní'
# 10400 'Jím' 'on-1' 'on-1'
# 10450 'Ve' 'v-1' 'v-1'
# 10500 'Pacient' 'pacient' 'pacient'
# 10550 'Jejich' 'jeho' 'jeho'
# 10600 'Potlačily' 'potlačit' 'potlačit'
# 709/709 - 79s - loss: 0.0140 - val_accuracy: 0.9663 - 79s/epoch - 111ms/step
# Epoch 16/25
# 10650 'Věda' 'věda' 'věda'
# 10700 'Jiří' 'Jiří' 'Jiří'
# 10750 'Obě' 'oba' 'oba'
# 10800 'Králíci' 'králík' 'králík'
# 10850 'Problém' 'problém' 'problém'
# 10900 'Ukazuje' 'ukazovat' 'ukazovat'
# 10950 'Někdo' 'někdo' 'někdo'
# 11000 'Kdo' 'kdo' 'kdo'
# 11050 'V' 'v-1' 'v-1'
# 11100 'Dlouhodobý' 'dlouhodobý' 'dlouhodobý'
# 11150 'Co' 'co-1' 'co-1'
# 11200 'Oba' 'oba' 'oba'
# 11250 'Trvalo' 'trvat' 'trvat'
# 11300 'Než' 'než-2' 'než-2'
# 709/709 - 78s - loss: 0.0137 - val_accuracy: 0.9667 - 78s/epoch - 111ms/step
# Epoch 17/25
# 11350 '"' '"' '"'
# 11400 'Třetiny' 'třetina' 'třetina'
# 11450 'O' 'o-1' 'o-1'
# 11500 '-' '-' '-'
# 11550 'V' 'v-1' 'v-1'
# 11600 'Samostatný' 'samostatný' 'samostatný'
# 11650 'Proti' 'proti-1' 'proti-1'
# 11700 'Přímořská' 'přímořský' 'přímořský'
# 11750 'K' 'k-1' 'k-1'
# 11800 '"' '"' '"'
# 11850 'Francie' 'Francie' 'Francie'
# 11900 'Projekt' 'projekt' 'projekt'
# 11950 'Máme' 'mít' 'mít'
# 12000 'Iluzorní' 'iluzorní' 'iluzorní'
# 12050 'Výše' 'výše' 'vysoko-1'
# 709/709 - 79s - loss: 0.0130 - val_accuracy: 0.9657 - 79s/epoch - 111ms/step
# Epoch 18/25
# 12100 'V' 'v-1' 'v-1'
# 12150 'Sociální' 'sociální' 'sociální'
# 12200 '%' '%' '%'
# 12250 '(' '(' '('
# 12300 'Na' 'na-1' 'na-1'
# 12350 'Dělníci' 'dělník' 'dělník'
# 12400 'Moby' 'Moby' 'Moby'
# 12450 'Rozdíl' 'rozdíl' 'rozdíl'
# 12500 'Možná' 'možná-1' 'možná-1'
# 12550 'Ekologické' 'ekologický' 'ekologický'
# 12600 'Ponechali' 'ponechat' 'ponechat'
# 12650 'Měl' 'mít' 'mít'
# 12700 'Foto' 'foto' 'foto'
# 12750 'A' 'a-1' 'a-1'
# 709/709 - 78s - loss: 0.0127 - val_accuracy: 0.9678 - 78s/epoch - 110ms/step
# Epoch 19/25
# 12800 'K' 'k-1' 'k-1'
# 12850 'Kolika' 'kolik' 'kolik'
# 12900 'To' 'ten' 'ten'
# 12950 'Praha' 'Praha' 'Praha'
# 13000 'V' 'v-1' 'v-1'
# 13050 'Některé' 'některý' 'některý'
# 13100 'Řekněte' 'říci' 'říci'
# 13150 'Most' 'Most-2' 'Most-2'
# 13200 'Oba' 'oba' 'oba'
# 13250 'Obrat' 'obrat-1' 'obrat-1'
# 13300 'Sofia' 'Sofie' 'Sofie'
# 13350 'Jak' 'jak-2' 'jak-3'
# 13400 'Praha' 'Praha' 'Praha'
# 13450 'Mezitím' 'mezitím' 'mezitím'
# 709/709 - 78s - loss: 0.0123 - val_accuracy: 0.9676 - 78s/epoch - 110ms/step
# Epoch 20/25
# 13500 'Všude' 'všude' 'všude'
# 13550 'Takový' 'takový' 'takový'
# 13600 'Dříve' 'dříve' 'dříve'
# 13650 'Celkem' 'celkem' 'celkem'
# 13700 'Thoresen' 'Thoresen' 'Thoresen'
# 13750 'V' 'v-1' 'v-1'
# 13800 'Tým' 'tým' 'tým'
# 13850 'Je' 'být' 'být'
# 13900 'Plzeň' 'Plzeň' 'Plzeň'
# 13950 'V' 'v-1' 'v-1'
# 14000 '|' '|' '|'
# 14050 'Druhá' 'druhý' 'druhý'
# 14100 'Do' 'do-1' 'do-1'
# 14150 'Už' 'už-2' 'už-1'
# 709/709 - 78s - loss: 0.0121 - val_accuracy: 0.9678 - 78s/epoch - 110ms/step
# Epoch 21/25
# 14200 'Nedávno' 'dávno-1' 'dávno-1'
# 14250 'Tento' 'tento' 'tento'
# 14300 'Vbrzku' 'vbrzku' 'vbrzku'
# 14350 'Základní' 'základní' 'základní'
# 14400 'Zdá' 'zdát' 'zdát'
# 14450 'Jistě' 'jistě' 'jistě'
# 14500 'Na' 'na-1' 'na-1'
# 14550 'Ctí' 'čest' 'Ctelinsko'
# 14600 'Zástupce' 'zástupce' 'zástupce'
# 14650 'Druhým' 'druhý' 'druhý'
# 14700 'Suková' 'Suková' 'Suková'
# 14750 'Dokončený' 'dokončený' 'dokončený'
# 14800 'Jisté' 'jistý' 'jistý'
# 14850 'Vykonávání' 'vykonávání' 'vykonávání'
# 709/709 - 78s - loss: 0.0116 - val_accuracy: 0.9673 - 78s/epoch - 110ms/step
# Epoch 22/25
# 14900 'Radost' 'radost' 'radost'
# 14950 'Darja' 'Darja' 'darja'
# 15000 'Jižní' 'jižní' 'jižní'
# 15050 'Jím' 'on-1' 'on-1'
# 15100 'Ve' 'v-1' 'v-1'
# 15150 'Pacient' 'pacient' 'pacient'
# 15200 'Jejich' 'jeho' 'jeho'
# 15250 'Potlačily' 'potlačit' 'potlačit'
# 15300 'Věda' 'věda' 'věda'
# 15350 'Jiří' 'Jiří' 'Jiří'
# 15400 'Obě' 'oba' 'oba'
# 15450 'Králíci' 'králík' 'králík'
# 15500 'Problém' 'problém' 'problém'
# 15550 'Ukazuje' 'ukazovat' 'ukazovat'
# 709/709 - 78s - loss: 0.0116 - val_accuracy: 0.9672 - 78s/epoch - 110ms/step
# Epoch 23/25
# 15600 'Někdo' 'někdo' 'někdo'
# 15650 'Kdo' 'kdo' 'kdo'
# 15700 'V' 'v-1' 'v-1'
# 15750 'Dlouhodobý' 'dlouhodobý' 'dlouhodobý'
# 15800 'Co' 'co-1' 'co-1'
# 15850 'Oba' 'oba' 'oba'
# 15900 'Trvalo' 'trvat' 'trvat'
# 15950 'Než' 'než-2' 'než-2'
# 16000 '"' '"' '"'
# 16050 'Třetiny' 'třetina' 'třetina'
# 16100 'O' 'o-1' 'o-1'
# 16150 '-' '-' '-'
# 16200 'V' 'v-1' 'v-1'
# 16250 'Samostatný' 'samostatný' 'samostatný'
# 16300 'Proti' 'proti-1' 'proti-1'
# 709/709 - 78s - loss: 0.0111 - val_accuracy: 0.9673 - 78s/epoch - 110ms/step
# Epoch 24/25
# 16350 'Přímořská' 'přímořský' 'přímořský'
# 16400 'K' 'k-1' 'k-1'
# 16450 '"' '"' '"'
# 16500 'Francie' 'Francie' 'Francie'
# 16550 'Projekt' 'projekt' 'projekt'
# 16600 'Máme' 'mít' 'mít'
# 16650 'Iluzorní' 'iluzorní' 'iluzorní'
# 16700 'Výše' 'výše' 'výše'
# 16750 'V' 'v-1' 'v-1'
# 16800 'Sociální' 'sociální' 'sociální'
# 16850 '%' '%' '%'
# 16900 '(' '(' '('
# 16950 'Na' 'na-1' 'na-1'
# 17000 'Dělníci' 'dělník' 'dělník'
# 709/709 - 79s - loss: 0.0110 - val_accuracy: 0.9677 - 79s/epoch - 111ms/step
# Epoch 25/25
# 17050 'Moby' 'Moby' 'Moby'
# 17100 'Rozdíl' 'rozdíl' 'rozdíl'
# 17150 'Možná' 'možná-1' 'možná-1'
# 17200 'Ekologické' 'ekologický' 'ekologický'
# 17250 'Ponechali' 'ponechat' 'ponechat'
# 17300 'Měl' 'mít' 'mít'
# 17350 'Foto' 'foto' 'foto'
# 17400 'A' 'a-1' 'a-1'
# 17450 'K' 'k-1' 'k-1'
# 17500 'Kolika' 'kolik' 'kolika'
# 17550 'To' 'ten' 'ten'
# 17600 'Praha' 'Praha' 'Praha'
# 17650 'V' 'v-1' 'v-1'
# 17700 'Některé' 'některý' 'některý'
# 709/709 - 79s - loss: 0.0110 - val_accuracy: 0.9691 - 79s/epoch - 112ms/step
